# %%
import sys  
sys.path.insert(0, './../')
import numpy as np
import bbdc2021 as bbdc
import pandas as pd
from importlib import reload
reload(bbdc)
import tensorflow as tf
from keras import layers
import keras
from keras import backend as K
import matplotlib.pyplot as plt
from matplotlib import colors 
import evaluation.evaluate as evaluate
from tqdm import tqdm

# %%
np.random.seed(1)
tf.random.set_seed(1)
pathToDataset = "dataset_fft_mel_l04_o02495_f32/"

# %%
def load_audio_for_classification(fileListName, datasetName, dataDirectory, pathToDataDir="./../data/", overallLength = 10, partLength=1):
    labelDf = pd.read_csv(pathToDataDir+fileListName)
    labelDf = labelDf.replace({"event_label": bbdc.LABEL_DICT})
    labelDf['duration'] = labelDf.offset - labelDf.onset
    
    first_file_string = '/' + labelDf['filename'][0][:-4] + '.csv'
    ## Features aller Files laden
    X = []
    Y = []
    fileList = []
    first_file_string = '/'+dataDirectory+'/' + labelDf['filename'][0][:-4] + '.csv'
    timepoints = np.genfromtxt(pathToDataDir+datasetName+first_file_string, delimiter=',')[:, 0]
    sizeOfSequences = int(partLength/overallLength*len(timepoints))
    currentFile = ""
    for index, row in tqdm(labelDf.iterrows()):
        if currentFile!=row["filename"]:
            currentFile = row["filename"].replace(".wav", ".csv")
            features = np.genfromtxt(pathToDataDir + datasetName + dataDirectory+currentFile, delimiter=',')
        partOfFeatures = features[np.where(np.logical_and(timepoints >= row["onset"],timepoints <= row["offset"]))]
        if len(partOfFeatures)<=sizeOfSequences:
            indices = np.where(np.logical_and(timepoints >= row["onset"],timepoints <= row["offset"]))[0]
            fileList.append(currentFile)
            X.append(features[indices[0]:indices[0]+sizeOfSequences, 1:])
            y = np.zeros(len(bbdc.LABEL_DICT))
            y[row["event_label"]]=1
            Y.append(y)
        elif len(partOfFeatures)>sizeOfSequences:
            fileList.append(currentFile)
            fileList.append(currentFile)
            X.append(partOfFeatures[:sizeOfSequences, 1:])
            X.append(partOfFeatures[-sizeOfSequences:, 1:])
            y = np.zeros(len(bbdc.LABEL_DICT))
            y[row["event_label"]]=1
            Y.append(y)
            Y.append(y)
    return np.array(X), np.array(Y), fileList

# %%
X_train_a, Y_train_a, trainFileList_a = bbdc.load_audioset("long_unbalanced_train_segments.csv", "unbalanced_fft_mel_l04_o02495_f32/", pathToDataDir="./../google_audioset/googleData/fft/")
X_validation_a, Y_validation_a, validationFileList_a = bbdc.load_audioset("long_balanced_train_segments.csv", "balanced_fft_mel_l04_o02495_f32/", pathToDataDir="./../google_audioset/googleData/fft/")
X_test_a, Y_test_a, testFileList_a = bbdc.load_audioset("long_eval_segments.csv", "eval_fft_mel_l04_o02495_f32/", pathToDataDir="./../google_audioset/googleData/fft/")
# Out:
# 16186it [08:32, 31.57it/s]
# 573it [00:19, 29.54it/s]
# 585it [00:19, 29.70it/s]

# %%
X_train_new = np.append(X_train_a, X_validation_a, axis=0)
X_train_new = np.append(X_train_new, X_test_a, axis=0)
Y_train_new = np.append(Y_train_a[:,1:], Y_validation_a[:,1:], axis=0)
Y_train_new = np.append(Y_train_new, Y_test_a[:,1:], axis=0)

shuffledIndices = np.random.permutation(X_train_new.shape[0])
X_train_new = X_train_new[shuffledIndices]
Y_train_new = Y_train_new[shuffledIndices]
length = len(shuffledIndices)
X_validation_new = X_train_new[int(0.8*length):int(0.9*length)]
Y_validation_new = Y_train_new[int(0.8*length):int(0.9*length)]
X_test_new = X_train_new[int(0.9*length):]
Y_test_new = Y_train_new[int(0.9*length):]
X_train_new = X_train_new[:int(0.8*length)]
Y_train_new = Y_train_new[:int(0.8*length)]

# %%
X_train, Y_train, trainFileList = load_audio_for_classification("train.csv", pathToDataset, "dev/")
X_validation, Y_validation, validationFileList = load_audio_for_classification("validation.csv", pathToDataset, "dev/")
X_test, Y_test, testFileList = load_audio_for_classification("test.csv", pathToDataset, "dev/")
# Out:
# 24009it [05:09, 77.51it/s]
# 3047it [00:38, 79.43it/s]
# 2988it [00:36, 82.28it/s]

# %%
channels = [32, 64, 30]
numClasses=12
padding = "same"
input_layer = layers.Input(shape=(None, 32))
#input_layer = layers.Input(shape=X_train_new[0].shape)
x = input_layer
x = layers.LSTM(100)(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(100, activation="relu")(x)
x = layers.Dense(32, activation="relu")(x)
x = layers.Dense(numClasses, activation="softmax")(x)

model = keras.models.Model(inputs=input_layer, outputs=x)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, 32)]        0
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               53200
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 100)               10100
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                3232
# _________________________________________________________________
# dense_2 (Dense)              (None, 13)                429
# =================================================================
# Total params: 66,961
# Trainable params: 66,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
channels = [25, 20, 15]
numClasses=12
padding = "same"
input_layer = layers.Input(shape=(None, 32))
#input_layer = layers.Input(shape=X_train_new[0].shape)
x = input_layer
x = layers.Conv1D(channels[0], kernel_size=3, padding=padding, activation='relu')(x)
x = layers.Conv1D(channels[0], kernel_size=3, padding=padding, activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling1D()(x)

x = layers.Conv1D(channels[1], kernel_size=3, padding=padding, activation='relu')(x)
x = layers.Conv1D(channels[1], kernel_size=3, padding=padding, activation='relu')(x)
x = layers.Conv1D(channels[1], kernel_size=3, padding=padding, activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling1D()(x)

x = layers.Conv1D(channels[2], kernel_size=3, padding=padding, activation='relu')(x)
x = layers.Conv1D(channels[2], kernel_size=3, padding=padding, activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Conv1D(numClasses, kernel_size=1, activation='relu')(x)
x = layers.GlobalMaxPooling1D()(x)
x = layers.Activation(keras.activations.softmax)(x)

model = keras.models.Model(inputs=input_layer, outputs=x)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, None, 32)]        0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, None, 25)          2425
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, None, 25)          1900
# _________________________________________________________________
# batch_normalization_3 (Batch (None, None, 25)          100
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, None, 25)          0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, None, 20)          1520
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, None, 20)          1220
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, None, 20)          1220
# _________________________________________________________________
# batch_normalization_4 (Batch (None, None, 20)          80
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, None, 20)          0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, None, 15)          915
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, None, 15)          690
# _________________________________________________________________
# batch_normalization_5 (Batch (None, None, 15)          60
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, None, 12)          192
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 12)                0
# _________________________________________________________________
# activation_1 (Activation)    (None, 12)                0
# =================================================================
# Total params: 10,322
# Trainable params: 10,202
# Non-trainable params: 120
# _________________________________________________________________

# %%
opt = keras.optimizers.Adam(learning_rate=0.001)
checkpoint = keras.callbacks.ModelCheckpoint('model.h5', verbose=1, monitor='val_loss',save_best_only=True, mode='auto')
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['mae', 'accuracy'])
history = model.fit(X_train, Y_train[:,1:], batch_size=64, epochs=100, shuffle=True, validation_data=(X_validation, Y_validation[:,1:]), callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 563/563 [==============================] - 6s 9ms/step - loss: 2.1438 - mae: 0.1370 - accuracy: 0.2877 - val_loss: 1.5474 - val_mae: 0.1056 - val_accuracy: 0.4958
#
# Epoch 00001: val_loss improved from inf to 1.54736, saving model to model.h5
# Epoch 2/100
# 563/563 [==============================] - 6s 10ms/step - loss: 1.4168 - mae: 0.1006 - accuracy: 0.5450 - val_loss: 1.2434 - val_mae: 0.0869 - val_accuracy: 0.6041
#
# Epoch 00002: val_loss improved from 1.54736 to 1.24336, saving model to model.h5
# Epoch 3/100
# 563/563 [==============================] - 5s 9ms/step - loss: 1.1645 - mae: 0.0843 - accuracy: 0.6330 - val_loss: 1.0736 - val_mae: 0.0785 - val_accuracy: 0.6588
#
# Epoch 00003: val_loss improved from 1.24336 to 1.07360, saving model to model.h5
# Epoch 4/100
# 563/563 [==============================] - 5s 8ms/step - loss: 1.0145 - mae: 0.0741 - accuracy: 0.6792 - val_loss: 0.9590 - val_mae: 0.0681 - val_accuracy: 0.7011
#
# Epoch 00004: val_loss improved from 1.07360 to 0.95903, saving model to model.h5
# Epoch 5/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.8921 - mae: 0.0660 - accuracy: 0.7164 - val_loss: 0.9490 - val_mae: 0.0657 - val_accuracy: 0.7009
#
# Epoch 00005: val_loss improved from 0.95903 to 0.94898, saving model to model.h5
# Epoch 6/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.8069 - mae: 0.0600 - accuracy: 0.7444 - val_loss: 0.8389 - val_mae: 0.0599 - val_accuracy: 0.7313
#
# Epoch 00006: val_loss improved from 0.94898 to 0.83886, saving model to model.h5
# Epoch 7/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.7423 - mae: 0.0554 - accuracy: 0.7660 - val_loss: 0.8534 - val_mae: 0.0582 - val_accuracy: 0.7313
#
# Epoch 00007: val_loss did not improve from 0.83886
# Epoch 8/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.6983 - mae: 0.0525 - accuracy: 0.7783 - val_loss: 0.7355 - val_mae: 0.0541 - val_accuracy: 0.7617
#
# Epoch 00008: val_loss improved from 0.83886 to 0.73549, saving model to model.h5
# Epoch 9/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.6704 - mae: 0.0504 - accuracy: 0.7889 - val_loss: 0.7254 - val_mae: 0.0500 - val_accuracy: 0.7697
#
# Epoch 00009: val_loss improved from 0.73549 to 0.72536, saving model to model.h5
# Epoch 10/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.6321 - mae: 0.0475 - accuracy: 0.8006 - val_loss: 0.6877 - val_mae: 0.0498 - val_accuracy: 0.7784
#
# Epoch 00010: val_loss improved from 0.72536 to 0.68768, saving model to model.h5
# Epoch 11/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.6148 - mae: 0.0464 - accuracy: 0.8043 - val_loss: 0.6435 - val_mae: 0.0459 - val_accuracy: 0.7912
#
# Epoch 00011: val_loss improved from 0.68768 to 0.64353, saving model to model.h5
# Epoch 12/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.5878 - mae: 0.0446 - accuracy: 0.8125 - val_loss: 0.6421 - val_mae: 0.0470 - val_accuracy: 0.7944
#
# Epoch 00012: val_loss improved from 0.64353 to 0.64211, saving model to model.h5
# Epoch 13/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.5661 - mae: 0.0431 - accuracy: 0.8201 - val_loss: 0.6775 - val_mae: 0.0470 - val_accuracy: 0.7840
#
# Epoch 00013: val_loss did not improve from 0.64211
# Epoch 14/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.5543 - mae: 0.0419 - accuracy: 0.8251 - val_loss: 0.6343 - val_mae: 0.0451 - val_accuracy: 0.7918
#
# Epoch 00014: val_loss improved from 0.64211 to 0.63431, saving model to model.h5
# Epoch 15/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.5257 - mae: 0.0403 - accuracy: 0.8305 - val_loss: 0.8209 - val_mae: 0.0523 - val_accuracy: 0.7465
#
# Epoch 00015: val_loss did not improve from 0.63431
# Epoch 16/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.5117 - mae: 0.0393 - accuracy: 0.8357 - val_loss: 0.6138 - val_mae: 0.0429 - val_accuracy: 0.8040
#
# Epoch 00016: val_loss improved from 0.63431 to 0.61380, saving model to model.h5
# Epoch 17/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4925 - mae: 0.0379 - accuracy: 0.8395 - val_loss: 0.7014 - val_mae: 0.0469 - val_accuracy: 0.7827
#
# Epoch 00017: val_loss did not improve from 0.61380
# Epoch 18/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.5000 - mae: 0.0383 - accuracy: 0.8381 - val_loss: 0.5744 - val_mae: 0.0395 - val_accuracy: 0.8179
#
# Epoch 00018: val_loss improved from 0.61380 to 0.57444, saving model to model.h5
# Epoch 19/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4805 - mae: 0.0371 - accuracy: 0.8443 - val_loss: 0.6178 - val_mae: 0.0421 - val_accuracy: 0.8036
#
# Epoch 00019: val_loss did not improve from 0.57444
# Epoch 20/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4639 - mae: 0.0360 - accuracy: 0.8498 - val_loss: 0.6021 - val_mae: 0.0422 - val_accuracy: 0.8055
#
# Epoch 00020: val_loss did not improve from 0.57444
# Epoch 21/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.4513 - mae: 0.0348 - accuracy: 0.8550 - val_loss: 0.6100 - val_mae: 0.0405 - val_accuracy: 0.8099
#
# Epoch 00021: val_loss did not improve from 0.57444
# Epoch 22/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4457 - mae: 0.0346 - accuracy: 0.8552 - val_loss: 0.5910 - val_mae: 0.0402 - val_accuracy: 0.8109
#
# Epoch 00022: val_loss did not improve from 0.57444
# Epoch 23/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.4350 - mae: 0.0338 - accuracy: 0.8599 - val_loss: 0.5620 - val_mae: 0.0388 - val_accuracy: 0.8211
#
# Epoch 00023: val_loss improved from 0.57444 to 0.56196, saving model to model.h5
# Epoch 24/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.4311 - mae: 0.0337 - accuracy: 0.8589 - val_loss: 0.5355 - val_mae: 0.0366 - val_accuracy: 0.8331
#
# Epoch 00024: val_loss improved from 0.56196 to 0.53551, saving model to model.h5
# Epoch 25/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.4272 - mae: 0.0333 - accuracy: 0.8613 - val_loss: 0.5611 - val_mae: 0.0391 - val_accuracy: 0.8231
#
# Epoch 00025: val_loss did not improve from 0.53551
# Epoch 26/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.4155 - mae: 0.0324 - accuracy: 0.8683 - val_loss: 0.5561 - val_mae: 0.0383 - val_accuracy: 0.8227
#
# Epoch 00026: val_loss did not improve from 0.53551
# Epoch 27/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.4079 - mae: 0.0321 - accuracy: 0.8695 - val_loss: 0.5680 - val_mae: 0.0365 - val_accuracy: 0.8300
#
# Epoch 00027: val_loss did not improve from 0.53551
# Epoch 28/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.4051 - mae: 0.0314 - accuracy: 0.8714 - val_loss: 0.6014 - val_mae: 0.0395 - val_accuracy: 0.8133
#
# Epoch 00028: val_loss did not improve from 0.53551
# Epoch 29/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.4010 - mae: 0.0313 - accuracy: 0.8690 - val_loss: 0.6096 - val_mae: 0.0388 - val_accuracy: 0.8112
#
# Epoch 00029: val_loss did not improve from 0.53551
# Epoch 30/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.4000 - mae: 0.0312 - accuracy: 0.8720 - val_loss: 0.5226 - val_mae: 0.0350 - val_accuracy: 0.8372
#
# Epoch 00030: val_loss improved from 0.53551 to 0.52259, saving model to model.h5
# Epoch 31/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.4006 - mae: 0.0308 - accuracy: 0.8717 - val_loss: 0.5387 - val_mae: 0.0360 - val_accuracy: 0.8313
#
# Epoch 00031: val_loss did not improve from 0.52259
# Epoch 32/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3809 - mae: 0.0300 - accuracy: 0.8771 - val_loss: 0.5683 - val_mae: 0.0361 - val_accuracy: 0.8259
#
# Epoch 00032: val_loss did not improve from 0.52259
# Epoch 33/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3764 - mae: 0.0294 - accuracy: 0.8787 - val_loss: 0.5187 - val_mae: 0.0353 - val_accuracy: 0.8435
#
# Epoch 00033: val_loss improved from 0.52259 to 0.51867, saving model to model.h5
# Epoch 34/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3691 - mae: 0.0290 - accuracy: 0.8796 - val_loss: 0.5099 - val_mae: 0.0344 - val_accuracy: 0.8374
#
# Epoch 00034: val_loss improved from 0.51867 to 0.50994, saving model to model.h5
# Epoch 35/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3725 - mae: 0.0293 - accuracy: 0.8771 - val_loss: 0.5517 - val_mae: 0.0347 - val_accuracy: 0.8298
#
# Epoch 00035: val_loss did not improve from 0.50994
# Epoch 36/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3727 - mae: 0.0291 - accuracy: 0.8775 - val_loss: 0.5364 - val_mae: 0.0351 - val_accuracy: 0.8344
#
# Epoch 00036: val_loss did not improve from 0.50994
# Epoch 37/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3710 - mae: 0.0289 - accuracy: 0.8810 - val_loss: 0.5292 - val_mae: 0.0330 - val_accuracy: 0.8428
#
# Epoch 00037: val_loss did not improve from 0.50994
# Epoch 38/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3621 - mae: 0.0284 - accuracy: 0.8829 - val_loss: 0.5109 - val_mae: 0.0351 - val_accuracy: 0.8348
#
# Epoch 00038: val_loss did not improve from 0.50994
# Epoch 39/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3525 - mae: 0.0277 - accuracy: 0.8856 - val_loss: 0.5373 - val_mae: 0.0355 - val_accuracy: 0.8350
#
# Epoch 00039: val_loss did not improve from 0.50994
# Epoch 40/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3452 - mae: 0.0274 - accuracy: 0.8863 - val_loss: 0.5129 - val_mae: 0.0339 - val_accuracy: 0.8411
#
# Epoch 00040: val_loss did not improve from 0.50994
# Epoch 41/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3558 - mae: 0.0281 - accuracy: 0.8834 - val_loss: 0.5363 - val_mae: 0.0366 - val_accuracy: 0.8279
#
# Epoch 00041: val_loss did not improve from 0.50994
# Epoch 42/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3446 - mae: 0.0272 - accuracy: 0.8893 - val_loss: 0.5481 - val_mae: 0.0362 - val_accuracy: 0.8244
#
# Epoch 00042: val_loss did not improve from 0.50994
# Epoch 43/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3397 - mae: 0.0271 - accuracy: 0.8871 - val_loss: 0.5073 - val_mae: 0.0334 - val_accuracy: 0.8409
#
# Epoch 00043: val_loss improved from 0.50994 to 0.50732, saving model to model.h5
# Epoch 44/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3434 - mae: 0.0272 - accuracy: 0.8874 - val_loss: 0.4948 - val_mae: 0.0322 - val_accuracy: 0.8483
#
# Epoch 00044: val_loss improved from 0.50732 to 0.49480, saving model to model.h5
# Epoch 45/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3279 - mae: 0.0261 - accuracy: 0.8922 - val_loss: 0.5106 - val_mae: 0.0325 - val_accuracy: 0.8413
#
# Epoch 00045: val_loss did not improve from 0.49480
# Epoch 46/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3330 - mae: 0.0265 - accuracy: 0.8918 - val_loss: 0.5217 - val_mae: 0.0341 - val_accuracy: 0.8381
#
# Epoch 00046: val_loss did not improve from 0.49480
# Epoch 47/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3352 - mae: 0.0266 - accuracy: 0.8896 - val_loss: 0.5670 - val_mae: 0.0367 - val_accuracy: 0.8214
#
# Epoch 00047: val_loss did not improve from 0.49480
# Epoch 48/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3192 - mae: 0.0256 - accuracy: 0.8956 - val_loss: 0.5035 - val_mae: 0.0323 - val_accuracy: 0.8465
#
# Epoch 00048: val_loss did not improve from 0.49480
# Epoch 49/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3302 - mae: 0.0259 - accuracy: 0.8939 - val_loss: 0.5339 - val_mae: 0.0333 - val_accuracy: 0.8400
#
# Epoch 00049: val_loss did not improve from 0.49480
# Epoch 50/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3238 - mae: 0.0258 - accuracy: 0.8937 - val_loss: 0.5112 - val_mae: 0.0323 - val_accuracy: 0.8442
#
# Epoch 00050: val_loss did not improve from 0.49480
# Epoch 51/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3169 - mae: 0.0252 - accuracy: 0.8957 - val_loss: 0.5353 - val_mae: 0.0337 - val_accuracy: 0.8368
#
# Epoch 00051: val_loss did not improve from 0.49480
# Epoch 52/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3173 - mae: 0.0253 - accuracy: 0.8956 - val_loss: 0.5161 - val_mae: 0.0340 - val_accuracy: 0.8376
#
# Epoch 00052: val_loss did not improve from 0.49480
# Epoch 53/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3144 - mae: 0.0251 - accuracy: 0.8982 - val_loss: 0.5647 - val_mae: 0.0348 - val_accuracy: 0.8290
#
# Epoch 00053: val_loss did not improve from 0.49480
# Epoch 54/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3072 - mae: 0.0245 - accuracy: 0.9000 - val_loss: 0.5227 - val_mae: 0.0314 - val_accuracy: 0.8500
#
# Epoch 00054: val_loss did not improve from 0.49480
# Epoch 55/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3197 - mae: 0.0254 - accuracy: 0.8948 - val_loss: 0.5007 - val_mae: 0.0317 - val_accuracy: 0.8457
#
# Epoch 00055: val_loss did not improve from 0.49480
# Epoch 56/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3024 - mae: 0.0243 - accuracy: 0.9016 - val_loss: 0.5053 - val_mae: 0.0319 - val_accuracy: 0.8478
#
# Epoch 00056: val_loss did not improve from 0.49480
# Epoch 57/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3056 - mae: 0.0242 - accuracy: 0.8995 - val_loss: 0.4973 - val_mae: 0.0318 - val_accuracy: 0.8452
#
# Epoch 00057: val_loss did not improve from 0.49480
# Epoch 58/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3005 - mae: 0.0241 - accuracy: 0.9007 - val_loss: 0.6058 - val_mae: 0.0352 - val_accuracy: 0.8196
#
# Epoch 00058: val_loss did not improve from 0.49480
# Epoch 59/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2978 - mae: 0.0240 - accuracy: 0.9013 - val_loss: 0.5288 - val_mae: 0.0326 - val_accuracy: 0.8411
#
# Epoch 00059: val_loss did not improve from 0.49480
# Epoch 60/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3040 - mae: 0.0243 - accuracy: 0.8989 - val_loss: 0.5140 - val_mae: 0.0322 - val_accuracy: 0.8476
#
# Epoch 00060: val_loss did not improve from 0.49480
# Epoch 61/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.2953 - mae: 0.0237 - accuracy: 0.9034 - val_loss: 0.4941 - val_mae: 0.0306 - val_accuracy: 0.8515
#
# Epoch 00061: val_loss improved from 0.49480 to 0.49410, saving model to model.h5
# Epoch 62/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.2914 - mae: 0.0236 - accuracy: 0.9019 - val_loss: 0.5060 - val_mae: 0.0314 - val_accuracy: 0.8452
#
# Epoch 00062: val_loss did not improve from 0.49410
# Epoch 63/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.2829 - mae: 0.0231 - accuracy: 0.9060 - val_loss: 0.5654 - val_mae: 0.0328 - val_accuracy: 0.8326
#
# Epoch 00063: val_loss did not improve from 0.49410
# Epoch 64/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2839 - mae: 0.0229 - accuracy: 0.9079 - val_loss: 0.4892 - val_mae: 0.0309 - val_accuracy: 0.8476
#
# Epoch 00064: val_loss improved from 0.49410 to 0.48918, saving model to model.h5
# Epoch 65/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2975 - mae: 0.0236 - accuracy: 0.9049 - val_loss: 0.4740 - val_mae: 0.0301 - val_accuracy: 0.8567
#
# Epoch 00065: val_loss improved from 0.48918 to 0.47401, saving model to model.h5
# Epoch 66/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2800 - mae: 0.0228 - accuracy: 0.9062 - val_loss: 0.6008 - val_mae: 0.0341 - val_accuracy: 0.8255
#
# Epoch 00066: val_loss did not improve from 0.47401
# Epoch 67/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2860 - mae: 0.0229 - accuracy: 0.9060 - val_loss: 0.5119 - val_mae: 0.0320 - val_accuracy: 0.8385
#
# Epoch 00067: val_loss did not improve from 0.47401
# Epoch 68/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2916 - mae: 0.0233 - accuracy: 0.9035 - val_loss: 0.5170 - val_mae: 0.0319 - val_accuracy: 0.8435
#
# Epoch 00068: val_loss did not improve from 0.47401
# Epoch 69/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2943 - mae: 0.0234 - accuracy: 0.9052 - val_loss: 0.5758 - val_mae: 0.0337 - val_accuracy: 0.8357
#
# Epoch 00069: val_loss did not improve from 0.47401
# Epoch 70/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2798 - mae: 0.0225 - accuracy: 0.9084 - val_loss: 0.5093 - val_mae: 0.0319 - val_accuracy: 0.8370
#
# Epoch 00070: val_loss did not improve from 0.47401
# Epoch 71/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2764 - mae: 0.0222 - accuracy: 0.9107 - val_loss: 0.5407 - val_mae: 0.0325 - val_accuracy: 0.8363
#
# Epoch 00071: val_loss did not improve from 0.47401
# Epoch 72/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2821 - mae: 0.0226 - accuracy: 0.9073 - val_loss: 0.5058 - val_mae: 0.0312 - val_accuracy: 0.8494
#
# Epoch 00072: val_loss did not improve from 0.47401
# Epoch 73/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2800 - mae: 0.0223 - accuracy: 0.9085 - val_loss: 0.4918 - val_mae: 0.0299 - val_accuracy: 0.8539
#
# Epoch 00073: val_loss did not improve from 0.47401
# Epoch 74/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2684 - mae: 0.0217 - accuracy: 0.9108 - val_loss: 0.5291 - val_mae: 0.0314 - val_accuracy: 0.8442
#
# Epoch 00074: val_loss did not improve from 0.47401
# Epoch 75/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.2791 - mae: 0.0225 - accuracy: 0.9068 - val_loss: 0.4869 - val_mae: 0.0293 - val_accuracy: 0.8554
#
# Epoch 00075: val_loss did not improve from 0.47401
# Epoch 76/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2581 - mae: 0.0211 - accuracy: 0.9147 - val_loss: 0.5511 - val_mae: 0.0319 - val_accuracy: 0.8426
#
# Epoch 00076: val_loss did not improve from 0.47401
# Epoch 77/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2786 - mae: 0.0224 - accuracy: 0.9060 - val_loss: 0.5118 - val_mae: 0.0299 - val_accuracy: 0.8494
#
# Epoch 00077: val_loss did not improve from 0.47401
# Epoch 78/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2640 - mae: 0.0210 - accuracy: 0.9158 - val_loss: 0.5703 - val_mae: 0.0340 - val_accuracy: 0.8292
#
# Epoch 00078: val_loss did not improve from 0.47401
# Epoch 79/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2755 - mae: 0.0220 - accuracy: 0.9092 - val_loss: 0.5371 - val_mae: 0.0316 - val_accuracy: 0.8407
#
# Epoch 00079: val_loss did not improve from 0.47401
# Epoch 80/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2652 - mae: 0.0214 - accuracy: 0.9123 - val_loss: 0.5031 - val_mae: 0.0302 - val_accuracy: 0.8504
#
# Epoch 00080: val_loss did not improve from 0.47401
# Epoch 81/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2690 - mae: 0.0216 - accuracy: 0.9139 - val_loss: 0.5355 - val_mae: 0.0299 - val_accuracy: 0.8530
#
# Epoch 00081: val_loss did not improve from 0.47401
# Epoch 82/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2689 - mae: 0.0215 - accuracy: 0.9107 - val_loss: 0.5429 - val_mae: 0.0310 - val_accuracy: 0.8435
#
# Epoch 00082: val_loss did not improve from 0.47401
# Epoch 83/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2642 - mae: 0.0214 - accuracy: 0.9124 - val_loss: 0.5398 - val_mae: 0.0313 - val_accuracy: 0.8437
#
# Epoch 00083: val_loss did not improve from 0.47401
# Epoch 84/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2621 - mae: 0.0213 - accuracy: 0.9110 - val_loss: 0.4901 - val_mae: 0.0297 - val_accuracy: 0.8524
#
# Epoch 00084: val_loss did not improve from 0.47401
# Epoch 85/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2641 - mae: 0.0213 - accuracy: 0.9119 - val_loss: 0.5340 - val_mae: 0.0300 - val_accuracy: 0.8517
#
# Epoch 00085: val_loss did not improve from 0.47401
# Epoch 86/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2547 - mae: 0.0206 - accuracy: 0.9150 - val_loss: 0.5115 - val_mae: 0.0306 - val_accuracy: 0.8474
#
# Epoch 00086: val_loss did not improve from 0.47401
# Epoch 87/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.2604 - mae: 0.0211 - accuracy: 0.9120 - val_loss: 0.5224 - val_mae: 0.0305 - val_accuracy: 0.8457
#
# Epoch 00087: val_loss did not improve from 0.47401
# Epoch 88/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2585 - mae: 0.0210 - accuracy: 0.9143 - val_loss: 0.5629 - val_mae: 0.0319 - val_accuracy: 0.8372
#
# Epoch 00088: val_loss did not improve from 0.47401
# Epoch 89/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.2487 - mae: 0.0205 - accuracy: 0.9155 - val_loss: 0.5506 - val_mae: 0.0318 - val_accuracy: 0.8405
#
# Epoch 00089: val_loss did not improve from 0.47401
# Epoch 90/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2573 - mae: 0.0208 - accuracy: 0.9157 - val_loss: 0.5437 - val_mae: 0.0304 - val_accuracy: 0.8468
#
# Epoch 00090: val_loss did not improve from 0.47401
# Epoch 91/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.2521 - mae: 0.0205 - accuracy: 0.9149 - val_loss: 0.5264 - val_mae: 0.0305 - val_accuracy: 0.8426
#
# Epoch 00091: val_loss did not improve from 0.47401
# Epoch 92/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2536 - mae: 0.0206 - accuracy: 0.9154 - val_loss: 0.5844 - val_mae: 0.0317 - val_accuracy: 0.8374
#
# Epoch 00092: val_loss did not improve from 0.47401
# Epoch 93/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.2538 - mae: 0.0208 - accuracy: 0.9153 - val_loss: 0.5279 - val_mae: 0.0306 - val_accuracy: 0.8483
#
# Epoch 00093: val_loss did not improve from 0.47401
# Epoch 94/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.2493 - mae: 0.0203 - accuracy: 0.9168 - val_loss: 0.5276 - val_mae: 0.0307 - val_accuracy: 0.8459
#
# Epoch 00094: val_loss did not improve from 0.47401
# Epoch 95/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2488 - mae: 0.0202 - accuracy: 0.9176 - val_loss: 0.5189 - val_mae: 0.0293 - val_accuracy: 0.8530
#
# Epoch 00095: val_loss did not improve from 0.47401
# Epoch 96/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.2418 - mae: 0.0194 - accuracy: 0.9231 - val_loss: 0.5290 - val_mae: 0.0306 - val_accuracy: 0.8468
#
# Epoch 00096: val_loss did not improve from 0.47401
# Epoch 97/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.2344 - mae: 0.0195 - accuracy: 0.9199 - val_loss: 0.5412 - val_mae: 0.0319 - val_accuracy: 0.8398
#
# Epoch 00097: val_loss did not improve from 0.47401
# Epoch 98/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.2343 - mae: 0.0195 - accuracy: 0.9219 - val_loss: 0.5274 - val_mae: 0.0291 - val_accuracy: 0.8520
#
# Epoch 00098: val_loss did not improve from 0.47401
# Epoch 99/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.2425 - mae: 0.0199 - accuracy: 0.9197 - val_loss: 0.5229 - val_mae: 0.0291 - val_accuracy: 0.8524
#
# Epoch 00099: val_loss did not improve from 0.47401
# Epoch 100/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.2487 - mae: 0.0201 - accuracy: 0.9169 - val_loss: 0.5142 - val_mae: 0.0306 - val_accuracy: 0.8476
#
# Epoch 00100: val_loss did not improve from 0.47401

# %%
opt = keras.optimizers.Adam(learning_rate=0.0005)
checkpoint = keras.callbacks.ModelCheckpoint('model.h5', verbose=1, monitor='val_loss',save_best_only=True, mode='auto')
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['mae', 'accuracy'])
history = model.fit(X_train_new, Y_train_new, batch_size=64, epochs=150, shuffle=True, validation_data=(X_validation_new, Y_validation_new), callbacks=[checkpoint])
# Out:
# Epoch 1/150
# 217/217 [==============================] - 15s 63ms/step - loss: 4.6381 - mae: 0.1134 - accuracy: 0.3486 - val_loss: 2.6861 - val_mae: 0.1096 - val_accuracy: 0.3858
#
# Epoch 00001: val_loss improved from inf to 2.68610, saving model to model.h5
# Epoch 2/150
# 217/217 [==============================] - 13s 61ms/step - loss: 2.2428 - mae: 0.1003 - accuracy: 0.4554 - val_loss: 2.0079 - val_mae: 0.1011 - val_accuracy: 0.4596
#
# Epoch 00002: val_loss improved from 2.68610 to 2.00794, saving model to model.h5
# Epoch 3/150
# 217/217 [==============================] - 13s 62ms/step - loss: 1.7762 - mae: 0.0971 - accuracy: 0.4985 - val_loss: 1.7914 - val_mae: 0.0964 - val_accuracy: 0.5035
#
# Epoch 00003: val_loss improved from 2.00794 to 1.79143, saving model to model.h5
# Epoch 4/150
# 217/217 [==============================] - 13s 61ms/step - loss: 1.6210 - mae: 0.0968 - accuracy: 0.5187 - val_loss: 1.6286 - val_mae: 0.0961 - val_accuracy: 0.5196
#
# Epoch 00004: val_loss improved from 1.79143 to 1.62857, saving model to model.h5
# Epoch 5/150
# 217/217 [==============================] - 13s 61ms/step - loss: 1.4887 - mae: 0.0946 - accuracy: 0.5421 - val_loss: 1.5855 - val_mae: 0.0945 - val_accuracy: 0.5300
#
# Epoch 00005: val_loss improved from 1.62857 to 1.58547, saving model to model.h5
# Epoch 6/150
# 217/217 [==============================] - 13s 62ms/step - loss: 1.4333 - mae: 0.0932 - accuracy: 0.5562 - val_loss: 1.4733 - val_mae: 0.0928 - val_accuracy: 0.5502
#
# Epoch 00006: val_loss improved from 1.58547 to 1.47329, saving model to model.h5
# Epoch 7/150
# 217/217 [==============================] - 14s 62ms/step - loss: 1.3734 - mae: 0.0918 - accuracy: 0.5693 - val_loss: 1.4409 - val_mae: 0.0919 - val_accuracy: 0.5646
#
# Epoch 00007: val_loss improved from 1.47329 to 1.44090, saving model to model.h5
# Epoch 8/150
# 217/217 [==============================] - 13s 62ms/step - loss: 1.3330 - mae: 0.0904 - accuracy: 0.5870 - val_loss: 1.4186 - val_mae: 0.0911 - val_accuracy: 0.5669
#
# Epoch 00008: val_loss improved from 1.44090 to 1.41856, saving model to model.h5
# Epoch 9/150
# 217/217 [==============================] - 13s 62ms/step - loss: 1.2890 - mae: 0.0891 - accuracy: 0.5910 - val_loss: 1.3630 - val_mae: 0.0909 - val_accuracy: 0.5813
#
# Epoch 00009: val_loss improved from 1.41856 to 1.36297, saving model to model.h5
# Epoch 10/150
# 217/217 [==============================] - 14s 65ms/step - loss: 1.2547 - mae: 0.0876 - accuracy: 0.6047 - val_loss: 1.3428 - val_mae: 0.0891 - val_accuracy: 0.5934
#
# Epoch 00010: val_loss improved from 1.36297 to 1.34279, saving model to model.h5
# Epoch 11/150
# 217/217 [==============================] - 13s 61ms/step - loss: 1.2000 - mae: 0.0856 - accuracy: 0.6200 - val_loss: 1.3250 - val_mae: 0.0879 - val_accuracy: 0.5992
#
# Epoch 00011: val_loss improved from 1.34279 to 1.32499, saving model to model.h5
# Epoch 12/150
# 217/217 [==============================] - 13s 62ms/step - loss: 1.1967 - mae: 0.0850 - accuracy: 0.6236 - val_loss: 1.3173 - val_mae: 0.0863 - val_accuracy: 0.5911
#
# Epoch 00012: val_loss improved from 1.32499 to 1.31725, saving model to model.h5
# Epoch 13/150
# 217/217 [==============================] - 13s 61ms/step - loss: 1.1745 - mae: 0.0850 - accuracy: 0.6280 - val_loss: 1.3017 - val_mae: 0.0832 - val_accuracy: 0.6119
#
# Epoch 00013: val_loss improved from 1.31725 to 1.30167, saving model to model.h5
# Epoch 14/150
# 217/217 [==============================] - 13s 62ms/step - loss: 1.1346 - mae: 0.0815 - accuracy: 0.6406 - val_loss: 1.2638 - val_mae: 0.0844 - val_accuracy: 0.6194
#
# Epoch 00014: val_loss improved from 1.30167 to 1.26383, saving model to model.h5
# Epoch 15/150
# 217/217 [==============================] - 13s 61ms/step - loss: 1.1265 - mae: 0.0813 - accuracy: 0.6395 - val_loss: 1.2479 - val_mae: 0.0831 - val_accuracy: 0.6211
#
# Epoch 00015: val_loss improved from 1.26383 to 1.24787, saving model to model.h5
# Epoch 16/150
# 217/217 [==============================] - 13s 62ms/step - loss: 1.0932 - mae: 0.0798 - accuracy: 0.6474 - val_loss: 1.2534 - val_mae: 0.0834 - val_accuracy: 0.6223
#
# Epoch 00016: val_loss did not improve from 1.24787
# Epoch 17/150
# 217/217 [==============================] - 13s 62ms/step - loss: 1.0885 - mae: 0.0803 - accuracy: 0.6477 - val_loss: 1.2353 - val_mae: 0.0810 - val_accuracy: 0.6292
#
# Epoch 00017: val_loss improved from 1.24787 to 1.23535, saving model to model.h5
# Epoch 18/150
# 217/217 [==============================] - 13s 61ms/step - loss: 1.0903 - mae: 0.0790 - accuracy: 0.6522 - val_loss: 1.2559 - val_mae: 0.0810 - val_accuracy: 0.6332
#
# Epoch 00018: val_loss did not improve from 1.23535
# Epoch 19/150
# 217/217 [==============================] - 13s 62ms/step - loss: 1.0496 - mae: 0.0766 - accuracy: 0.6633 - val_loss: 1.2185 - val_mae: 0.0816 - val_accuracy: 0.6286
#
# Epoch 00019: val_loss improved from 1.23535 to 1.21853, saving model to model.h5
# Epoch 20/150
# 217/217 [==============================] - 13s 62ms/step - loss: 1.0151 - mae: 0.0756 - accuracy: 0.6733 - val_loss: 1.2104 - val_mae: 0.0808 - val_accuracy: 0.6309
#
# Epoch 00020: val_loss improved from 1.21853 to 1.21038, saving model to model.h5
# Epoch 21/150
# 217/217 [==============================] - 13s 61ms/step - loss: 1.0258 - mae: 0.0758 - accuracy: 0.6776 - val_loss: 1.2070 - val_mae: 0.0812 - val_accuracy: 0.6401
#
# Epoch 00021: val_loss improved from 1.21038 to 1.20704, saving model to model.h5
# Epoch 22/150
# 217/217 [==============================] - 13s 61ms/step - loss: 1.0190 - mae: 0.0753 - accuracy: 0.6758 - val_loss: 1.1879 - val_mae: 0.0785 - val_accuracy: 0.6436
#
# Epoch 00022: val_loss improved from 1.20704 to 1.18794, saving model to model.h5
# Epoch 23/150
# 217/217 [==============================] - 14s 62ms/step - loss: 0.9945 - mae: 0.0741 - accuracy: 0.6847 - val_loss: 1.1861 - val_mae: 0.0789 - val_accuracy: 0.6488
#
# Epoch 00023: val_loss improved from 1.18794 to 1.18609, saving model to model.h5
# Epoch 24/150
# 217/217 [==============================] - 13s 62ms/step - loss: 0.9880 - mae: 0.0732 - accuracy: 0.6856 - val_loss: 1.1949 - val_mae: 0.0770 - val_accuracy: 0.6378
#
# Epoch 00024: val_loss did not improve from 1.18609
# Epoch 25/150
# 217/217 [==============================] - 13s 62ms/step - loss: 0.9607 - mae: 0.0716 - accuracy: 0.6959 - val_loss: 1.1795 - val_mae: 0.0776 - val_accuracy: 0.6390
#
# Epoch 00025: val_loss improved from 1.18609 to 1.17953, saving model to model.h5
# Epoch 26/150
# 217/217 [==============================] - 13s 61ms/step - loss: 0.9569 - mae: 0.0722 - accuracy: 0.6904 - val_loss: 1.1629 - val_mae: 0.0755 - val_accuracy: 0.6569
#
# Epoch 00026: val_loss improved from 1.17953 to 1.16295, saving model to model.h5
# Epoch 27/150
# 217/217 [==============================] - 13s 62ms/step - loss: 0.9456 - mae: 0.0718 - accuracy: 0.6971 - val_loss: 1.1801 - val_mae: 0.0763 - val_accuracy: 0.6476
#
# Epoch 00027: val_loss did not improve from 1.16295
# Epoch 28/150
# 217/217 [==============================] - 14s 63ms/step - loss: 0.9381 - mae: 0.0705 - accuracy: 0.6983 - val_loss: 1.1992 - val_mae: 0.0756 - val_accuracy: 0.6419
#
# Epoch 00028: val_loss did not improve from 1.16295
# Epoch 29/150
# 217/217 [==============================] - 13s 62ms/step - loss: 0.9161 - mae: 0.0698 - accuracy: 0.7010 - val_loss: 1.1578 - val_mae: 0.0746 - val_accuracy: 0.6528
#
# Epoch 00029: val_loss improved from 1.16295 to 1.15785, saving model to model.h5
# Epoch 30/150
# 217/217 [==============================] - 14s 63ms/step - loss: 0.9080 - mae: 0.0697 - accuracy: 0.7016 - val_loss: 1.1861 - val_mae: 0.0757 - val_accuracy: 0.6534
#
# Epoch 00030: val_loss did not improve from 1.15785
# Epoch 31/150
# 217/217 [==============================] - 13s 62ms/step - loss: 0.9141 - mae: 0.0698 - accuracy: 0.7048 - val_loss: 1.1586 - val_mae: 0.0753 - val_accuracy: 0.6632
#
# Epoch 00031: val_loss did not improve from 1.15785
# Epoch 32/150
# 217/217 [==============================] - 13s 61ms/step - loss: 0.8914 - mae: 0.0683 - accuracy: 0.7111 - val_loss: 1.1731 - val_mae: 0.0752 - val_accuracy: 0.6494
#
# Epoch 00032: val_loss did not improve from 1.15785
# Epoch 33/150
# 217/217 [==============================] - 14s 63ms/step - loss: 0.8801 - mae: 0.0672 - accuracy: 0.7165 - val_loss: 1.1567 - val_mae: 0.0743 - val_accuracy: 0.6551
#
# Epoch 00033: val_loss improved from 1.15785 to 1.15673, saving model to model.h5
# Epoch 34/150
# 217/217 [==============================] - 14s 63ms/step - loss: 0.8509 - mae: 0.0658 - accuracy: 0.7269 - val_loss: 1.1769 - val_mae: 0.0757 - val_accuracy: 0.6517
#
# Epoch 00034: val_loss did not improve from 1.15673
# Epoch 35/150
# 217/217 [==============================] - 13s 62ms/step - loss: 0.8438 - mae: 0.0655 - accuracy: 0.7277 - val_loss: 1.1648 - val_mae: 0.0748 - val_accuracy: 0.6540
#
# Epoch 00035: val_loss did not improve from 1.15673
# Epoch 36/150
# 217/217 [==============================] - 13s 62ms/step - loss: 0.8594 - mae: 0.0663 - accuracy: 0.7190 - val_loss: 1.1610 - val_mae: 0.0742 - val_accuracy: 0.6574
#
# Epoch 00036: val_loss did not improve from 1.15673
# Epoch 37/150
# 217/217 [==============================] - 14s 63ms/step - loss: 0.8582 - mae: 0.0653 - accuracy: 0.7227 - val_loss: 1.1990 - val_mae: 0.0745 - val_accuracy: 0.6557
#
# Epoch 00037: val_loss did not improve from 1.15673
# Epoch 38/150
# 217/217 [==============================] - 14s 65ms/step - loss: 0.8461 - mae: 0.0649 - accuracy: 0.7259 - val_loss: 1.1504 - val_mae: 0.0732 - val_accuracy: 0.6586
#
# Epoch 00038: val_loss improved from 1.15673 to 1.15041, saving model to model.h5
# Epoch 39/150
# 217/217 [==============================] - 14s 64ms/step - loss: 0.8200 - mae: 0.0637 - accuracy: 0.7283 - val_loss: 1.1704 - val_mae: 0.0732 - val_accuracy: 0.6522
#
# Epoch 00039: val_loss did not improve from 1.15041
# Epoch 40/150
# 217/217 [==============================] - 14s 64ms/step - loss: 0.8306 - mae: 0.0643 - accuracy: 0.7295 - val_loss: 1.1526 - val_mae: 0.0735 - val_accuracy: 0.6563
#
# Epoch 00040: val_loss did not improve from 1.15041
# Epoch 41/150
# 217/217 [==============================] - 13s 62ms/step - loss: 0.8209 - mae: 0.0636 - accuracy: 0.7299 - val_loss: 1.1639 - val_mae: 0.0734 - val_accuracy: 0.6534
#
# Epoch 00041: val_loss did not improve from 1.15041
# Epoch 42/150
# 217/217 [==============================] - 13s 62ms/step - loss: 0.8151 - mae: 0.0635 - accuracy: 0.7379 - val_loss: 1.1803 - val_mae: 0.0727 - val_accuracy: 0.6586
#
# Epoch 00042: val_loss did not improve from 1.15041
# Epoch 43/150
# 217/217 [==============================] - 15s 69ms/step - loss: 0.8093 - mae: 0.0629 - accuracy: 0.7375 - val_loss: 1.1694 - val_mae: 0.0728 - val_accuracy: 0.6557
#
# Epoch 00043: val_loss did not improve from 1.15041
# Epoch 44/150
# 217/217 [==============================] - 14s 63ms/step - loss: 0.7959 - mae: 0.0623 - accuracy: 0.7398 - val_loss: 1.1939 - val_mae: 0.0721 - val_accuracy: 0.6499
#
# Epoch 00044: val_loss did not improve from 1.15041
# Epoch 45/150
# 217/217 [==============================] - 12s 54ms/step - loss: 0.7970 - mae: 0.0617 - accuracy: 0.7419 - val_loss: 1.1700 - val_mae: 0.0742 - val_accuracy: 0.6499
#
# Epoch 00045: val_loss did not improve from 1.15041
# Epoch 46/150
# 217/217 [==============================] - 13s 58ms/step - loss: 0.7731 - mae: 0.0610 - accuracy: 0.7463 - val_loss: 1.2170 - val_mae: 0.0721 - val_accuracy: 0.6609
#
# Epoch 00046: val_loss did not improve from 1.15041
# Epoch 47/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.7756 - mae: 0.0607 - accuracy: 0.7468 - val_loss: 1.1842 - val_mae: 0.0711 - val_accuracy: 0.6551
#
# Epoch 00047: val_loss did not improve from 1.15041
# Epoch 48/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.7871 - mae: 0.0615 - accuracy: 0.7469 - val_loss: 1.1863 - val_mae: 0.0702 - val_accuracy: 0.6661
#
# Epoch 00048: val_loss did not improve from 1.15041
# Epoch 49/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.7631 - mae: 0.0603 - accuracy: 0.7523 - val_loss: 1.1724 - val_mae: 0.0709 - val_accuracy: 0.6580
#
# Epoch 00049: val_loss did not improve from 1.15041
# Epoch 50/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.7671 - mae: 0.0599 - accuracy: 0.7507 - val_loss: 1.1834 - val_mae: 0.0717 - val_accuracy: 0.6557
#
# Epoch 00050: val_loss did not improve from 1.15041
# Epoch 51/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.7491 - mae: 0.0590 - accuracy: 0.7552 - val_loss: 1.2032 - val_mae: 0.0712 - val_accuracy: 0.6621
#
# Epoch 00051: val_loss did not improve from 1.15041
# Epoch 52/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.7186 - mae: 0.0577 - accuracy: 0.7630 - val_loss: 1.1966 - val_mae: 0.0699 - val_accuracy: 0.6586
#
# Epoch 00052: val_loss did not improve from 1.15041
# Epoch 53/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.7507 - mae: 0.0591 - accuracy: 0.7514 - val_loss: 1.2104 - val_mae: 0.0698 - val_accuracy: 0.6569
#
# Epoch 00053: val_loss did not improve from 1.15041
# Epoch 54/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.7241 - mae: 0.0575 - accuracy: 0.7614 - val_loss: 1.2067 - val_mae: 0.0706 - val_accuracy: 0.6511
#
# Epoch 00054: val_loss did not improve from 1.15041
# Epoch 55/150
# 217/217 [==============================] - 11s 51ms/step - loss: 0.7339 - mae: 0.0575 - accuracy: 0.7618 - val_loss: 1.2215 - val_mae: 0.0725 - val_accuracy: 0.6430
#
# Epoch 00055: val_loss did not improve from 1.15041
# Epoch 56/150
# 217/217 [==============================] - 11s 51ms/step - loss: 0.7229 - mae: 0.0577 - accuracy: 0.7657 - val_loss: 1.2119 - val_mae: 0.0713 - val_accuracy: 0.6453
#
# Epoch 00056: val_loss did not improve from 1.15041
# Epoch 57/150
# 217/217 [==============================] - 11s 51ms/step - loss: 0.7014 - mae: 0.0563 - accuracy: 0.7650 - val_loss: 1.2119 - val_mae: 0.0728 - val_accuracy: 0.6522
#
# Epoch 00057: val_loss did not improve from 1.15041
# Epoch 58/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.7192 - mae: 0.0573 - accuracy: 0.7645 - val_loss: 1.2224 - val_mae: 0.0739 - val_accuracy: 0.6430
#
# Epoch 00058: val_loss did not improve from 1.15041
# Epoch 59/150
# 217/217 [==============================] - 11s 53ms/step - loss: 0.7100 - mae: 0.0570 - accuracy: 0.7704 - val_loss: 1.2133 - val_mae: 0.0718 - val_accuracy: 0.6471
#
# Epoch 00059: val_loss did not improve from 1.15041
# Epoch 60/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.6874 - mae: 0.0553 - accuracy: 0.7794 - val_loss: 1.2313 - val_mae: 0.0703 - val_accuracy: 0.6540
#
# Epoch 00060: val_loss did not improve from 1.15041
# Epoch 61/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.6956 - mae: 0.0556 - accuracy: 0.7680 - val_loss: 1.2141 - val_mae: 0.0708 - val_accuracy: 0.6476
#
# Epoch 00061: val_loss did not improve from 1.15041
# Epoch 62/150
# 217/217 [==============================] - 11s 53ms/step - loss: 0.6934 - mae: 0.0559 - accuracy: 0.7701 - val_loss: 1.2209 - val_mae: 0.0710 - val_accuracy: 0.6557
#
# Epoch 00062: val_loss did not improve from 1.15041
# Epoch 63/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.6771 - mae: 0.0546 - accuracy: 0.7794 - val_loss: 1.2604 - val_mae: 0.0728 - val_accuracy: 0.6361
#
# Epoch 00063: val_loss did not improve from 1.15041
# Epoch 64/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.6831 - mae: 0.0547 - accuracy: 0.7824 - val_loss: 1.2299 - val_mae: 0.0701 - val_accuracy: 0.6494
#
# Epoch 00064: val_loss did not improve from 1.15041
# Epoch 65/150
# 217/217 [==============================] - 12s 54ms/step - loss: 0.6498 - mae: 0.0527 - accuracy: 0.7874 - val_loss: 1.2119 - val_mae: 0.0715 - val_accuracy: 0.6476
#
# Epoch 00065: val_loss did not improve from 1.15041
# Epoch 66/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.6785 - mae: 0.0542 - accuracy: 0.7843 - val_loss: 1.2429 - val_mae: 0.0717 - val_accuracy: 0.6338
#
# Epoch 00066: val_loss did not improve from 1.15041
# Epoch 67/150
# 217/217 [==============================] - 12s 57ms/step - loss: 0.6668 - mae: 0.0536 - accuracy: 0.7861 - val_loss: 1.2506 - val_mae: 0.0700 - val_accuracy: 0.6390
#
# Epoch 00067: val_loss did not improve from 1.15041
# Epoch 68/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.6594 - mae: 0.0529 - accuracy: 0.7857 - val_loss: 1.2423 - val_mae: 0.0692 - val_accuracy: 0.6453
#
# Epoch 00068: val_loss did not improve from 1.15041
# Epoch 69/150
# 217/217 [==============================] - 11s 51ms/step - loss: 0.6519 - mae: 0.0526 - accuracy: 0.7898 - val_loss: 1.2538 - val_mae: 0.0713 - val_accuracy: 0.6338
#
# Epoch 00069: val_loss did not improve from 1.15041
# Epoch 70/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.6555 - mae: 0.0524 - accuracy: 0.7859 - val_loss: 1.2597 - val_mae: 0.0692 - val_accuracy: 0.6540
#
# Epoch 00070: val_loss did not improve from 1.15041
# Epoch 71/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.6409 - mae: 0.0520 - accuracy: 0.7927 - val_loss: 1.2622 - val_mae: 0.0717 - val_accuracy: 0.6321
#
# Epoch 00071: val_loss did not improve from 1.15041
# Epoch 72/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.6388 - mae: 0.0515 - accuracy: 0.7965 - val_loss: 1.2595 - val_mae: 0.0724 - val_accuracy: 0.6424
#
# Epoch 00072: val_loss did not improve from 1.15041
# Epoch 73/150
# 217/217 [==============================] - 11s 53ms/step - loss: 0.6569 - mae: 0.0526 - accuracy: 0.7921 - val_loss: 1.2853 - val_mae: 0.0709 - val_accuracy: 0.6424
#
# Epoch 00073: val_loss did not improve from 1.15041
# Epoch 74/150
# 217/217 [==============================] - 11s 51ms/step - loss: 0.6393 - mae: 0.0513 - accuracy: 0.7940 - val_loss: 1.2667 - val_mae: 0.0692 - val_accuracy: 0.6534
#
# Epoch 00074: val_loss did not improve from 1.15041
# Epoch 75/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.6418 - mae: 0.0518 - accuracy: 0.7920 - val_loss: 1.2877 - val_mae: 0.0726 - val_accuracy: 0.6367
#
# Epoch 00075: val_loss did not improve from 1.15041
# Epoch 76/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.6169 - mae: 0.0501 - accuracy: 0.8026 - val_loss: 1.3740 - val_mae: 0.0733 - val_accuracy: 0.6263
#
# Epoch 00076: val_loss did not improve from 1.15041
# Epoch 77/150
# 217/217 [==============================] - 11s 53ms/step - loss: 0.6040 - mae: 0.0494 - accuracy: 0.8058 - val_loss: 1.3145 - val_mae: 0.0693 - val_accuracy: 0.6361
#
# Epoch 00077: val_loss did not improve from 1.15041
# Epoch 78/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.6086 - mae: 0.0498 - accuracy: 0.7981 - val_loss: 1.2831 - val_mae: 0.0712 - val_accuracy: 0.6326
#
# Epoch 00078: val_loss did not improve from 1.15041
# Epoch 79/150
# 217/217 [==============================] - 11s 51ms/step - loss: 0.6122 - mae: 0.0500 - accuracy: 0.8054 - val_loss: 1.2643 - val_mae: 0.0701 - val_accuracy: 0.6413
#
# Epoch 00079: val_loss did not improve from 1.15041
# Epoch 80/150
# 217/217 [==============================] - 11s 51ms/step - loss: 0.6240 - mae: 0.0504 - accuracy: 0.7935 - val_loss: 1.3430 - val_mae: 0.0731 - val_accuracy: 0.6205
#
# Epoch 00080: val_loss did not improve from 1.15041
# Epoch 81/150
# 217/217 [==============================] - 12s 55ms/step - loss: 0.6084 - mae: 0.0491 - accuracy: 0.8023 - val_loss: 1.2901 - val_mae: 0.0679 - val_accuracy: 0.6499
#
# Epoch 00081: val_loss did not improve from 1.15041
# Epoch 82/150
# 217/217 [==============================] - 12s 53ms/step - loss: 0.6030 - mae: 0.0488 - accuracy: 0.8047 - val_loss: 1.3108 - val_mae: 0.0687 - val_accuracy: 0.6430
#
# Epoch 00082: val_loss did not improve from 1.15041
# Epoch 83/150
# 217/217 [==============================] - 11s 53ms/step - loss: 0.5980 - mae: 0.0487 - accuracy: 0.8082 - val_loss: 1.3067 - val_mae: 0.0689 - val_accuracy: 0.6442
#
# Epoch 00083: val_loss did not improve from 1.15041
# Epoch 84/150
# 217/217 [==============================] - 12s 53ms/step - loss: 0.5975 - mae: 0.0483 - accuracy: 0.8068 - val_loss: 1.2981 - val_mae: 0.0701 - val_accuracy: 0.6436
#
# Epoch 00084: val_loss did not improve from 1.15041
# Epoch 85/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.5822 - mae: 0.0480 - accuracy: 0.8083 - val_loss: 1.3029 - val_mae: 0.0700 - val_accuracy: 0.6430
#
# Epoch 00085: val_loss did not improve from 1.15041
# Epoch 86/150
# 217/217 [==============================] - 11s 53ms/step - loss: 0.5886 - mae: 0.0483 - accuracy: 0.8109 - val_loss: 1.3310 - val_mae: 0.0710 - val_accuracy: 0.6286
#
# Epoch 00086: val_loss did not improve from 1.15041
# Epoch 87/150
# 217/217 [==============================] - 11s 53ms/step - loss: 0.5771 - mae: 0.0472 - accuracy: 0.8134 - val_loss: 1.3547 - val_mae: 0.0709 - val_accuracy: 0.6326
#
# Epoch 00087: val_loss did not improve from 1.15041
# Epoch 88/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.5748 - mae: 0.0472 - accuracy: 0.8141 - val_loss: 1.3557 - val_mae: 0.0712 - val_accuracy: 0.6286
#
# Epoch 00088: val_loss did not improve from 1.15041
# Epoch 89/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.5872 - mae: 0.0478 - accuracy: 0.8104 - val_loss: 1.3332 - val_mae: 0.0691 - val_accuracy: 0.6476
#
# Epoch 00089: val_loss did not improve from 1.15041
# Epoch 90/150
# 217/217 [==============================] - 11s 53ms/step - loss: 0.5692 - mae: 0.0471 - accuracy: 0.8111 - val_loss: 1.3302 - val_mae: 0.0701 - val_accuracy: 0.6424
#
# Epoch 00090: val_loss did not improve from 1.15041
# Epoch 91/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.5836 - mae: 0.0471 - accuracy: 0.8110 - val_loss: 1.3318 - val_mae: 0.0680 - val_accuracy: 0.6413
#
# Epoch 00091: val_loss did not improve from 1.15041
# Epoch 92/150
# 217/217 [==============================] - 11s 53ms/step - loss: 0.5781 - mae: 0.0468 - accuracy: 0.8136 - val_loss: 1.3338 - val_mae: 0.0692 - val_accuracy: 0.6453
#
# Epoch 00092: val_loss did not improve from 1.15041
# Epoch 93/150
# 217/217 [==============================] - 11s 52ms/step - loss: 0.5700 - mae: 0.0468 - accuracy: 0.8142 - val_loss: 1.3325 - val_mae: 0.0699 - val_accuracy: 0.6355
#
# Epoch 00093: val_loss did not improve from 1.15041
# Epoch 94/150
# 217/217 [==============================] - 8s 38ms/step - loss: 0.5675 - mae: 0.0470 - accuracy: 0.8141 - val_loss: 1.3471 - val_mae: 0.0685 - val_accuracy: 0.6419
#
# Epoch 00094: val_loss did not improve from 1.15041
# Epoch 95/150
# 217/217 [==============================] - 8s 38ms/step - loss: 0.5565 - mae: 0.0463 - accuracy: 0.8117 - val_loss: 1.3660 - val_mae: 0.0710 - val_accuracy: 0.6182
#
# Epoch 00095: val_loss did not improve from 1.15041
# Epoch 96/150
# 217/217 [==============================] - 8s 38ms/step - loss: 0.5472 - mae: 0.0453 - accuracy: 0.8207 - val_loss: 1.3503 - val_mae: 0.0696 - val_accuracy: 0.6378
#
# Epoch 00096: val_loss did not improve from 1.15041
# Epoch 97/150
# 217/217 [==============================] - 8s 38ms/step - loss: 0.5438 - mae: 0.0456 - accuracy: 0.8221 - val_loss: 1.3785 - val_mae: 0.0690 - val_accuracy: 0.6349
#
# Epoch 00097: val_loss did not improve from 1.15041
# Epoch 98/150
# 217/217 [==============================] - 8s 38ms/step - loss: 0.5367 - mae: 0.0447 - accuracy: 0.8249 - val_loss: 1.3654 - val_mae: 0.0700 - val_accuracy: 0.6338
#
# Epoch 00098: val_loss did not improve from 1.15041
# Epoch 99/150
# 217/217 [==============================] - 8s 38ms/step - loss: 0.5667 - mae: 0.0463 - accuracy: 0.8108 - val_loss: 1.3841 - val_mae: 0.0707 - val_accuracy: 0.6292
#
# Epoch 00099: val_loss did not improve from 1.15041
# Epoch 100/150
# 217/217 [==============================] - 8s 38ms/step - loss: 0.5331 - mae: 0.0444 - accuracy: 0.8281 - val_loss: 1.3597 - val_mae: 0.0697 - val_accuracy: 0.6355
#
# Epoch 00100: val_loss did not improve from 1.15041
# Epoch 101/150
# 217/217 [==============================] - 8s 38ms/step - loss: 0.5324 - mae: 0.0442 - accuracy: 0.8304 - val_loss: 1.4048 - val_mae: 0.0726 - val_accuracy: 0.6153
#
# Epoch 00101: val_loss did not improve from 1.15041
# Epoch 102/150
# 217/217 [==============================] - 9s 42ms/step - loss: 0.5270 - mae: 0.0441 - accuracy: 0.8281 - val_loss: 1.4215 - val_mae: 0.0701 - val_accuracy: 0.6280
#
# Epoch 00102: val_loss did not improve from 1.15041
# Epoch 103/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.5459 - mae: 0.0446 - accuracy: 0.8290 - val_loss: 1.3538 - val_mae: 0.0686 - val_accuracy: 0.6373
#
# Epoch 00103: val_loss did not improve from 1.15041
# Epoch 104/150
# 217/217 [==============================] - 10s 48ms/step - loss: 0.5428 - mae: 0.0449 - accuracy: 0.8265 - val_loss: 1.3768 - val_mae: 0.0679 - val_accuracy: 0.6355
#
# Epoch 00104: val_loss did not improve from 1.15041
# Epoch 105/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.5416 - mae: 0.0443 - accuracy: 0.8245 - val_loss: 1.4033 - val_mae: 0.0708 - val_accuracy: 0.6211
#
# Epoch 00105: val_loss did not improve from 1.15041
# Epoch 106/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.5199 - mae: 0.0435 - accuracy: 0.8291 - val_loss: 1.4316 - val_mae: 0.0719 - val_accuracy: 0.6171
#
# Epoch 00106: val_loss did not improve from 1.15041
# Epoch 107/150
# 217/217 [==============================] - 10s 48ms/step - loss: 0.5292 - mae: 0.0439 - accuracy: 0.8271 - val_loss: 1.3849 - val_mae: 0.0700 - val_accuracy: 0.6257
#
# Epoch 00107: val_loss did not improve from 1.15041
# Epoch 108/150
# 217/217 [==============================] - 11s 48ms/step - loss: 0.5238 - mae: 0.0438 - accuracy: 0.8287 - val_loss: 1.4414 - val_mae: 0.0717 - val_accuracy: 0.6153
#
# Epoch 00108: val_loss did not improve from 1.15041
# Epoch 109/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.5364 - mae: 0.0438 - accuracy: 0.8271 - val_loss: 1.4059 - val_mae: 0.0694 - val_accuracy: 0.6292
#
# Epoch 00109: val_loss did not improve from 1.15041
# Epoch 110/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.5271 - mae: 0.0440 - accuracy: 0.8256 - val_loss: 1.4190 - val_mae: 0.0704 - val_accuracy: 0.6228
#
# Epoch 00110: val_loss did not improve from 1.15041
# Epoch 111/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.5183 - mae: 0.0432 - accuracy: 0.8272 - val_loss: 1.4428 - val_mae: 0.0717 - val_accuracy: 0.6113
#
# Epoch 00111: val_loss did not improve from 1.15041
# Epoch 112/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.5319 - mae: 0.0434 - accuracy: 0.8314 - val_loss: 1.4194 - val_mae: 0.0700 - val_accuracy: 0.6246
#
# Epoch 00112: val_loss did not improve from 1.15041
# Epoch 113/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.5198 - mae: 0.0433 - accuracy: 0.8299 - val_loss: 1.4098 - val_mae: 0.0686 - val_accuracy: 0.6401
#
# Epoch 00113: val_loss did not improve from 1.15041
# Epoch 114/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.5134 - mae: 0.0427 - accuracy: 0.8326 - val_loss: 1.4703 - val_mae: 0.0687 - val_accuracy: 0.6280
#
# Epoch 00114: val_loss did not improve from 1.15041
# Epoch 115/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.5014 - mae: 0.0420 - accuracy: 0.8380 - val_loss: 1.4442 - val_mae: 0.0689 - val_accuracy: 0.6234
#
# Epoch 00115: val_loss did not improve from 1.15041
# Epoch 116/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.5050 - mae: 0.0423 - accuracy: 0.8356 - val_loss: 1.4881 - val_mae: 0.0723 - val_accuracy: 0.6136
#
# Epoch 00116: val_loss did not improve from 1.15041
# Epoch 117/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.5024 - mae: 0.0415 - accuracy: 0.8394 - val_loss: 1.4625 - val_mae: 0.0711 - val_accuracy: 0.6148
#
# Epoch 00117: val_loss did not improve from 1.15041
# Epoch 118/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.5002 - mae: 0.0417 - accuracy: 0.8365 - val_loss: 1.4726 - val_mae: 0.0700 - val_accuracy: 0.6275
#
# Epoch 00118: val_loss did not improve from 1.15041
# Epoch 119/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.5188 - mae: 0.0426 - accuracy: 0.8314 - val_loss: 1.4785 - val_mae: 0.0699 - val_accuracy: 0.6211
#
# Epoch 00119: val_loss did not improve from 1.15041
# Epoch 120/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.5265 - mae: 0.0429 - accuracy: 0.8289 - val_loss: 1.4562 - val_mae: 0.0685 - val_accuracy: 0.6344
#
# Epoch 00120: val_loss did not improve from 1.15041
# Epoch 121/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.4928 - mae: 0.0412 - accuracy: 0.8404 - val_loss: 1.4459 - val_mae: 0.0707 - val_accuracy: 0.6165
#
# Epoch 00121: val_loss did not improve from 1.15041
# Epoch 122/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.5183 - mae: 0.0423 - accuracy: 0.8342 - val_loss: 1.4447 - val_mae: 0.0701 - val_accuracy: 0.6136
#
# Epoch 00122: val_loss did not improve from 1.15041
# Epoch 123/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.4825 - mae: 0.0408 - accuracy: 0.8442 - val_loss: 1.4483 - val_mae: 0.0702 - val_accuracy: 0.6176
#
# Epoch 00123: val_loss did not improve from 1.15041
# Epoch 124/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.4976 - mae: 0.0407 - accuracy: 0.8451 - val_loss: 1.4739 - val_mae: 0.0704 - val_accuracy: 0.6171
#
# Epoch 00124: val_loss did not improve from 1.15041
# Epoch 125/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.4833 - mae: 0.0408 - accuracy: 0.8415 - val_loss: 1.5044 - val_mae: 0.0679 - val_accuracy: 0.6326
#
# Epoch 00125: val_loss did not improve from 1.15041
# Epoch 126/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.4904 - mae: 0.0408 - accuracy: 0.8435 - val_loss: 1.5012 - val_mae: 0.0708 - val_accuracy: 0.6176
#
# Epoch 00126: val_loss did not improve from 1.15041
# Epoch 127/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.4887 - mae: 0.0411 - accuracy: 0.8422 - val_loss: 1.5465 - val_mae: 0.0697 - val_accuracy: 0.6263
#
# Epoch 00127: val_loss did not improve from 1.15041
# Epoch 128/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.4846 - mae: 0.0406 - accuracy: 0.8403 - val_loss: 1.4757 - val_mae: 0.0690 - val_accuracy: 0.6298
#
# Epoch 00128: val_loss did not improve from 1.15041
# Epoch 129/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.4614 - mae: 0.0391 - accuracy: 0.8500 - val_loss: 1.4975 - val_mae: 0.0690 - val_accuracy: 0.6217
#
# Epoch 00129: val_loss did not improve from 1.15041
# Epoch 130/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.5063 - mae: 0.0413 - accuracy: 0.8375 - val_loss: 1.4964 - val_mae: 0.0703 - val_accuracy: 0.6130
#
# Epoch 00130: val_loss did not improve from 1.15041
# Epoch 131/150
# 217/217 [==============================] - 11s 51ms/step - loss: 0.4793 - mae: 0.0401 - accuracy: 0.8443 - val_loss: 1.5131 - val_mae: 0.0701 - val_accuracy: 0.6142
#
# Epoch 00131: val_loss did not improve from 1.15041
# Epoch 132/150
# 217/217 [==============================] - 11s 51ms/step - loss: 0.4787 - mae: 0.0404 - accuracy: 0.8417 - val_loss: 1.5104 - val_mae: 0.0692 - val_accuracy: 0.6246
#
# Epoch 00132: val_loss did not improve from 1.15041
# Epoch 133/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.4788 - mae: 0.0400 - accuracy: 0.8412 - val_loss: 1.5069 - val_mae: 0.0682 - val_accuracy: 0.6292
#
# Epoch 00133: val_loss did not improve from 1.15041
# Epoch 134/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.4742 - mae: 0.0400 - accuracy: 0.8472 - val_loss: 1.5113 - val_mae: 0.0678 - val_accuracy: 0.6344
#
# Epoch 00134: val_loss did not improve from 1.15041
# Epoch 135/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.4691 - mae: 0.0394 - accuracy: 0.8500 - val_loss: 1.5212 - val_mae: 0.0712 - val_accuracy: 0.6096
#
# Epoch 00135: val_loss did not improve from 1.15041
# Epoch 136/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.4684 - mae: 0.0396 - accuracy: 0.8453 - val_loss: 1.5153 - val_mae: 0.0687 - val_accuracy: 0.6292
#
# Epoch 00136: val_loss did not improve from 1.15041
# Epoch 137/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.4747 - mae: 0.0393 - accuracy: 0.8440 - val_loss: 1.5995 - val_mae: 0.0686 - val_accuracy: 0.6246
#
# Epoch 00137: val_loss did not improve from 1.15041
# Epoch 138/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.4603 - mae: 0.0388 - accuracy: 0.8521 - val_loss: 1.5061 - val_mae: 0.0700 - val_accuracy: 0.6292
#
# Epoch 00138: val_loss did not improve from 1.15041
# Epoch 139/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.4706 - mae: 0.0393 - accuracy: 0.8480 - val_loss: 1.5482 - val_mae: 0.0702 - val_accuracy: 0.6171
#
# Epoch 00139: val_loss did not improve from 1.15041
# Epoch 140/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.4674 - mae: 0.0393 - accuracy: 0.8484 - val_loss: 1.5268 - val_mae: 0.0683 - val_accuracy: 0.6263
#
# Epoch 00140: val_loss did not improve from 1.15041
# Epoch 141/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.4640 - mae: 0.0390 - accuracy: 0.8512 - val_loss: 1.5329 - val_mae: 0.0688 - val_accuracy: 0.6188
#
# Epoch 00141: val_loss did not improve from 1.15041
# Epoch 142/150
# 217/217 [==============================] - 11s 51ms/step - loss: 0.4544 - mae: 0.0384 - accuracy: 0.8527 - val_loss: 1.5717 - val_mae: 0.0684 - val_accuracy: 0.6246
#
# Epoch 00142: val_loss did not improve from 1.15041
# Epoch 143/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.4666 - mae: 0.0394 - accuracy: 0.8457 - val_loss: 1.7463 - val_mae: 0.0745 - val_accuracy: 0.5923
#
# Epoch 00143: val_loss did not improve from 1.15041
# Epoch 144/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.4899 - mae: 0.0405 - accuracy: 0.8373 - val_loss: 1.5386 - val_mae: 0.0701 - val_accuracy: 0.6211
#
# Epoch 00144: val_loss did not improve from 1.15041
# Epoch 145/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.4339 - mae: 0.0373 - accuracy: 0.8577 - val_loss: 1.5376 - val_mae: 0.0688 - val_accuracy: 0.6234
#
# Epoch 00145: val_loss did not improve from 1.15041
# Epoch 146/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.4386 - mae: 0.0375 - accuracy: 0.8532 - val_loss: 1.5779 - val_mae: 0.0682 - val_accuracy: 0.6194
#
# Epoch 00146: val_loss did not improve from 1.15041
# Epoch 147/150
# 217/217 [==============================] - 11s 50ms/step - loss: 0.4343 - mae: 0.0372 - accuracy: 0.8598 - val_loss: 1.5616 - val_mae: 0.0685 - val_accuracy: 0.6275
#
# Epoch 00147: val_loss did not improve from 1.15041
# Epoch 148/150
# 217/217 [==============================] - 10s 48ms/step - loss: 0.4533 - mae: 0.0375 - accuracy: 0.8565 - val_loss: 1.5627 - val_mae: 0.0692 - val_accuracy: 0.6275
#
# Epoch 00148: val_loss did not improve from 1.15041
# Epoch 149/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.4432 - mae: 0.0378 - accuracy: 0.8534 - val_loss: 1.5658 - val_mae: 0.0692 - val_accuracy: 0.6200
#
# Epoch 00149: val_loss did not improve from 1.15041
# Epoch 150/150
# 217/217 [==============================] - 11s 49ms/step - loss: 0.4472 - mae: 0.0376 - accuracy: 0.8535 - val_loss: 1.5921 - val_mae: 0.0691 - val_accuracy: 0.6251
#
# Epoch 00150: val_loss did not improve from 1.15041

# %%
opt = keras.optimizers.Adam(learning_rate=0.0001)
checkpoint = keras.callbacks.ModelCheckpoint('model.h5', verbose=1, monitor='val_loss',save_best_only=True, mode='auto')
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['mae', 'accuracy'])
history = model.fit(X_train, Y_train[:,1:], batch_size=64, epochs=100, shuffle=True, validation_data=(X_validation, Y_validation[:,1:]), callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 563/563 [==============================] - 6s 9ms/step - loss: 2.7518 - mae: 0.0942 - accuracy: 0.4592 - val_loss: 1.7992 - val_mae: 0.0769 - val_accuracy: 0.5700
#
# Epoch 00001: val_loss improved from inf to 1.79916, saving model to model.h5
# Epoch 2/100
# 563/563 [==============================] - 5s 8ms/step - loss: 1.6437 - mae: 0.0735 - accuracy: 0.5953 - val_loss: 1.4385 - val_mae: 0.0695 - val_accuracy: 0.6210
#
# Epoch 00002: val_loss improved from 1.79916 to 1.43847, saving model to model.h5
# Epoch 3/100
# 563/563 [==============================] - 5s 9ms/step - loss: 1.3505 - mae: 0.0675 - accuracy: 0.6367 - val_loss: 1.2377 - val_mae: 0.0645 - val_accuracy: 0.6560
#
# Epoch 00003: val_loss improved from 1.43847 to 1.23769, saving model to model.h5
# Epoch 4/100
# 563/563 [==============================] - 5s 8ms/step - loss: 1.1742 - mae: 0.0626 - accuracy: 0.6700 - val_loss: 1.1055 - val_mae: 0.0605 - val_accuracy: 0.6859
#
# Epoch 00004: val_loss improved from 1.23769 to 1.10552, saving model to model.h5
# Epoch 5/100
# 563/563 [==============================] - 5s 8ms/step - loss: 1.0604 - mae: 0.0587 - accuracy: 0.6981 - val_loss: 1.0108 - val_mae: 0.0577 - val_accuracy: 0.6998
#
# Epoch 00005: val_loss improved from 1.10552 to 1.01077, saving model to model.h5
# Epoch 6/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.9656 - mae: 0.0560 - accuracy: 0.7188 - val_loss: 0.9444 - val_mae: 0.0549 - val_accuracy: 0.7254
#
# Epoch 00006: val_loss improved from 1.01077 to 0.94437, saving model to model.h5
# Epoch 7/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.8723 - mae: 0.0528 - accuracy: 0.7378 - val_loss: 0.8827 - val_mae: 0.0527 - val_accuracy: 0.7391
#
# Epoch 00007: val_loss improved from 0.94437 to 0.88269, saving model to model.h5
# Epoch 8/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.8191 - mae: 0.0505 - accuracy: 0.7548 - val_loss: 0.8346 - val_mae: 0.0506 - val_accuracy: 0.7543
#
# Epoch 00008: val_loss improved from 0.88269 to 0.83463, saving model to model.h5
# Epoch 9/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.7746 - mae: 0.0487 - accuracy: 0.7635 - val_loss: 0.7971 - val_mae: 0.0490 - val_accuracy: 0.7654
#
# Epoch 00009: val_loss improved from 0.83463 to 0.79713, saving model to model.h5
# Epoch 10/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.7263 - mae: 0.0471 - accuracy: 0.7755 - val_loss: 0.7658 - val_mae: 0.0472 - val_accuracy: 0.7714
#
# Epoch 00010: val_loss improved from 0.79713 to 0.76580, saving model to model.h5
# Epoch 11/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.6962 - mae: 0.0455 - accuracy: 0.7850 - val_loss: 0.7316 - val_mae: 0.0457 - val_accuracy: 0.7803
#
# Epoch 00011: val_loss improved from 0.76580 to 0.73165, saving model to model.h5
# Epoch 12/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.6635 - mae: 0.0443 - accuracy: 0.7914 - val_loss: 0.7069 - val_mae: 0.0447 - val_accuracy: 0.7860
#
# Epoch 00012: val_loss improved from 0.73165 to 0.70691, saving model to model.h5
# Epoch 13/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.6245 - mae: 0.0425 - accuracy: 0.8045 - val_loss: 0.6846 - val_mae: 0.0435 - val_accuracy: 0.7931
#
# Epoch 00013: val_loss improved from 0.70691 to 0.68457, saving model to model.h5
# Epoch 14/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.5948 - mae: 0.0411 - accuracy: 0.8107 - val_loss: 0.6663 - val_mae: 0.0426 - val_accuracy: 0.7981
#
# Epoch 00014: val_loss improved from 0.68457 to 0.66632, saving model to model.h5
# Epoch 15/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.5747 - mae: 0.0401 - accuracy: 0.8166 - val_loss: 0.6497 - val_mae: 0.0416 - val_accuracy: 0.8049
#
# Epoch 00015: val_loss improved from 0.66632 to 0.64967, saving model to model.h5
# Epoch 16/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.5675 - mae: 0.0393 - accuracy: 0.8219 - val_loss: 0.6352 - val_mae: 0.0408 - val_accuracy: 0.8103
#
# Epoch 00016: val_loss improved from 0.64967 to 0.63523, saving model to model.h5
# Epoch 17/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.5391 - mae: 0.0381 - accuracy: 0.8271 - val_loss: 0.6184 - val_mae: 0.0399 - val_accuracy: 0.8168
#
# Epoch 00017: val_loss improved from 0.63523 to 0.61845, saving model to model.h5
# Epoch 18/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.5302 - mae: 0.0374 - accuracy: 0.8321 - val_loss: 0.6053 - val_mae: 0.0391 - val_accuracy: 0.8177
#
# Epoch 00018: val_loss improved from 0.61845 to 0.60530, saving model to model.h5
# Epoch 19/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.5113 - mae: 0.0367 - accuracy: 0.8374 - val_loss: 0.5922 - val_mae: 0.0388 - val_accuracy: 0.8242
#
# Epoch 00019: val_loss improved from 0.60530 to 0.59221, saving model to model.h5
# Epoch 20/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.4882 - mae: 0.0356 - accuracy: 0.8412 - val_loss: 0.5856 - val_mae: 0.0383 - val_accuracy: 0.8229
#
# Epoch 00020: val_loss improved from 0.59221 to 0.58563, saving model to model.h5
# Epoch 21/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4821 - mae: 0.0349 - accuracy: 0.8437 - val_loss: 0.5762 - val_mae: 0.0380 - val_accuracy: 0.8244
#
# Epoch 00021: val_loss improved from 0.58563 to 0.57622, saving model to model.h5
# Epoch 22/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4732 - mae: 0.0344 - accuracy: 0.8493 - val_loss: 0.5630 - val_mae: 0.0371 - val_accuracy: 0.8300
#
# Epoch 00022: val_loss improved from 0.57622 to 0.56297, saving model to model.h5
# Epoch 23/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.4558 - mae: 0.0339 - accuracy: 0.8511 - val_loss: 0.5537 - val_mae: 0.0369 - val_accuracy: 0.8333
#
# Epoch 00023: val_loss improved from 0.56297 to 0.55367, saving model to model.h5
# Epoch 24/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4493 - mae: 0.0334 - accuracy: 0.8537 - val_loss: 0.5496 - val_mae: 0.0365 - val_accuracy: 0.8355
#
# Epoch 00024: val_loss improved from 0.55367 to 0.54958, saving model to model.h5
# Epoch 25/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4334 - mae: 0.0327 - accuracy: 0.8591 - val_loss: 0.5444 - val_mae: 0.0359 - val_accuracy: 0.8363
#
# Epoch 00025: val_loss improved from 0.54958 to 0.54436, saving model to model.h5
# Epoch 26/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4290 - mae: 0.0324 - accuracy: 0.8600 - val_loss: 0.5364 - val_mae: 0.0359 - val_accuracy: 0.8339
#
# Epoch 00026: val_loss improved from 0.54436 to 0.53641, saving model to model.h5
# Epoch 27/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4151 - mae: 0.0315 - accuracy: 0.8657 - val_loss: 0.5329 - val_mae: 0.0356 - val_accuracy: 0.8359
#
# Epoch 00027: val_loss improved from 0.53641 to 0.53285, saving model to model.h5
# Epoch 28/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4126 - mae: 0.0316 - accuracy: 0.8641 - val_loss: 0.5277 - val_mae: 0.0349 - val_accuracy: 0.8392
#
# Epoch 00028: val_loss improved from 0.53285 to 0.52772, saving model to model.h5
# Epoch 29/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4044 - mae: 0.0308 - accuracy: 0.8675 - val_loss: 0.5245 - val_mae: 0.0348 - val_accuracy: 0.8407
#
# Epoch 00029: val_loss improved from 0.52772 to 0.52452, saving model to model.h5
# Epoch 30/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4077 - mae: 0.0308 - accuracy: 0.8680 - val_loss: 0.5230 - val_mae: 0.0345 - val_accuracy: 0.8398
#
# Epoch 00030: val_loss improved from 0.52452 to 0.52297, saving model to model.h5
# Epoch 31/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4077 - mae: 0.0308 - accuracy: 0.8648 - val_loss: 0.5163 - val_mae: 0.0345 - val_accuracy: 0.8405
#
# Epoch 00031: val_loss improved from 0.52297 to 0.51629, saving model to model.h5
# Epoch 32/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3907 - mae: 0.0301 - accuracy: 0.8704 - val_loss: 0.5122 - val_mae: 0.0341 - val_accuracy: 0.8422
#
# Epoch 00032: val_loss improved from 0.51629 to 0.51217, saving model to model.h5
# Epoch 33/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3863 - mae: 0.0295 - accuracy: 0.8744 - val_loss: 0.5076 - val_mae: 0.0339 - val_accuracy: 0.8435
#
# Epoch 00033: val_loss improved from 0.51217 to 0.50757, saving model to model.h5
# Epoch 34/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3783 - mae: 0.0292 - accuracy: 0.8755 - val_loss: 0.5062 - val_mae: 0.0336 - val_accuracy: 0.8468
#
# Epoch 00034: val_loss improved from 0.50757 to 0.50617, saving model to model.h5
# Epoch 35/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3728 - mae: 0.0290 - accuracy: 0.8774 - val_loss: 0.5018 - val_mae: 0.0333 - val_accuracy: 0.8481
#
# Epoch 00035: val_loss improved from 0.50617 to 0.50175, saving model to model.h5
# Epoch 36/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3715 - mae: 0.0289 - accuracy: 0.8792 - val_loss: 0.5026 - val_mae: 0.0331 - val_accuracy: 0.8474
#
# Epoch 00036: val_loss did not improve from 0.50175
# Epoch 37/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3613 - mae: 0.0284 - accuracy: 0.8797 - val_loss: 0.5034 - val_mae: 0.0333 - val_accuracy: 0.8442
#
# Epoch 00037: val_loss did not improve from 0.50175
# Epoch 38/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3634 - mae: 0.0283 - accuracy: 0.8810 - val_loss: 0.4986 - val_mae: 0.0328 - val_accuracy: 0.8489
#
# Epoch 00038: val_loss improved from 0.50175 to 0.49856, saving model to model.h5
# Epoch 39/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3563 - mae: 0.0276 - accuracy: 0.8835 - val_loss: 0.4983 - val_mae: 0.0328 - val_accuracy: 0.8474
#
# Epoch 00039: val_loss improved from 0.49856 to 0.49827, saving model to model.h5
# Epoch 40/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3437 - mae: 0.0273 - accuracy: 0.8851 - val_loss: 0.4992 - val_mae: 0.0327 - val_accuracy: 0.8474
#
# Epoch 00040: val_loss did not improve from 0.49827
# Epoch 41/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3505 - mae: 0.0273 - accuracy: 0.8870 - val_loss: 0.4955 - val_mae: 0.0323 - val_accuracy: 0.8489
#
# Epoch 00041: val_loss improved from 0.49827 to 0.49554, saving model to model.h5
# Epoch 42/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3443 - mae: 0.0269 - accuracy: 0.8857 - val_loss: 0.4921 - val_mae: 0.0322 - val_accuracy: 0.8489
#
# Epoch 00042: val_loss improved from 0.49554 to 0.49205, saving model to model.h5
# Epoch 43/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3402 - mae: 0.0266 - accuracy: 0.8896 - val_loss: 0.4912 - val_mae: 0.0322 - val_accuracy: 0.8511
#
# Epoch 00043: val_loss improved from 0.49205 to 0.49116, saving model to model.h5
# Epoch 44/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3423 - mae: 0.0267 - accuracy: 0.8888 - val_loss: 0.4941 - val_mae: 0.0322 - val_accuracy: 0.8481
#
# Epoch 00044: val_loss did not improve from 0.49116
# Epoch 45/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.3248 - mae: 0.0259 - accuracy: 0.8928 - val_loss: 0.4883 - val_mae: 0.0317 - val_accuracy: 0.8517
#
# Epoch 00045: val_loss improved from 0.49116 to 0.48831, saving model to model.h5
# Epoch 46/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.3397 - mae: 0.0267 - accuracy: 0.8885 - val_loss: 0.4863 - val_mae: 0.0315 - val_accuracy: 0.8524
#
# Epoch 00046: val_loss improved from 0.48831 to 0.48633, saving model to model.h5
# Epoch 47/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3288 - mae: 0.0260 - accuracy: 0.8930 - val_loss: 0.4880 - val_mae: 0.0317 - val_accuracy: 0.8520
#
# Epoch 00047: val_loss did not improve from 0.48633
# Epoch 48/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3176 - mae: 0.0254 - accuracy: 0.8952 - val_loss: 0.4875 - val_mae: 0.0313 - val_accuracy: 0.8539
#
# Epoch 00048: val_loss did not improve from 0.48633
# Epoch 49/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3240 - mae: 0.0256 - accuracy: 0.8949 - val_loss: 0.4862 - val_mae: 0.0315 - val_accuracy: 0.8526
#
# Epoch 00049: val_loss improved from 0.48633 to 0.48616, saving model to model.h5
# Epoch 50/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3189 - mae: 0.0254 - accuracy: 0.8952 - val_loss: 0.4870 - val_mae: 0.0311 - val_accuracy: 0.8559
#
# Epoch 00050: val_loss did not improve from 0.48616
# Epoch 51/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3138 - mae: 0.0249 - accuracy: 0.8988 - val_loss: 0.4830 - val_mae: 0.0312 - val_accuracy: 0.8548
#
# Epoch 00051: val_loss improved from 0.48616 to 0.48305, saving model to model.h5
# Epoch 52/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3120 - mae: 0.0250 - accuracy: 0.8976 - val_loss: 0.4859 - val_mae: 0.0312 - val_accuracy: 0.8530
#
# Epoch 00052: val_loss did not improve from 0.48305
# Epoch 53/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3088 - mae: 0.0248 - accuracy: 0.8999 - val_loss: 0.4843 - val_mae: 0.0312 - val_accuracy: 0.8559
#
# Epoch 00053: val_loss did not improve from 0.48305
# Epoch 54/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.3068 - mae: 0.0245 - accuracy: 0.8992 - val_loss: 0.4855 - val_mae: 0.0309 - val_accuracy: 0.8537
#
# Epoch 00054: val_loss did not improve from 0.48305
# Epoch 55/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.3071 - mae: 0.0245 - accuracy: 0.9005 - val_loss: 0.4874 - val_mae: 0.0309 - val_accuracy: 0.8552
#
# Epoch 00055: val_loss did not improve from 0.48305
# Epoch 56/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.2975 - mae: 0.0242 - accuracy: 0.9006 - val_loss: 0.4847 - val_mae: 0.0308 - val_accuracy: 0.8535
#
# Epoch 00056: val_loss did not improve from 0.48305
# Epoch 57/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.2982 - mae: 0.0238 - accuracy: 0.9046 - val_loss: 0.4832 - val_mae: 0.0304 - val_accuracy: 0.8570
#
# Epoch 00057: val_loss did not improve from 0.48305
# Epoch 58/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.2976 - mae: 0.0241 - accuracy: 0.9001 - val_loss: 0.4838 - val_mae: 0.0306 - val_accuracy: 0.8570
#
# Epoch 00058: val_loss did not improve from 0.48305
# Epoch 59/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.2953 - mae: 0.0238 - accuracy: 0.9036 - val_loss: 0.4850 - val_mae: 0.0304 - val_accuracy: 0.8554
#
# Epoch 00059: val_loss did not improve from 0.48305
# Epoch 60/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.2916 - mae: 0.0236 - accuracy: 0.9025 - val_loss: 0.4848 - val_mae: 0.0307 - val_accuracy: 0.8572
#
# Epoch 00060: val_loss did not improve from 0.48305
# Epoch 61/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.2942 - mae: 0.0237 - accuracy: 0.9018 - val_loss: 0.4827 - val_mae: 0.0302 - val_accuracy: 0.8576
#
# Epoch 00061: val_loss improved from 0.48305 to 0.48267, saving model to model.h5
# Epoch 62/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2889 - mae: 0.0234 - accuracy: 0.9034 - val_loss: 0.4831 - val_mae: 0.0302 - val_accuracy: 0.8572
#
# Epoch 00062: val_loss did not improve from 0.48267
# Epoch 63/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2850 - mae: 0.0231 - accuracy: 0.9058 - val_loss: 0.4836 - val_mae: 0.0301 - val_accuracy: 0.8580
#
# Epoch 00063: val_loss did not improve from 0.48267
# Epoch 64/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2781 - mae: 0.0228 - accuracy: 0.9085 - val_loss: 0.4838 - val_mae: 0.0300 - val_accuracy: 0.8585
#
# Epoch 00064: val_loss did not improve from 0.48267
# Epoch 65/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2900 - mae: 0.0234 - accuracy: 0.9048 - val_loss: 0.4852 - val_mae: 0.0300 - val_accuracy: 0.8563
#
# Epoch 00065: val_loss did not improve from 0.48267
# Epoch 66/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2781 - mae: 0.0226 - accuracy: 0.9105 - val_loss: 0.4836 - val_mae: 0.0300 - val_accuracy: 0.8557
#
# Epoch 00066: val_loss did not improve from 0.48267
# Epoch 67/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2815 - mae: 0.0225 - accuracy: 0.9095 - val_loss: 0.4841 - val_mae: 0.0299 - val_accuracy: 0.8591
#
# Epoch 00067: val_loss did not improve from 0.48267
# Epoch 68/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2854 - mae: 0.0230 - accuracy: 0.9074 - val_loss: 0.4807 - val_mae: 0.0299 - val_accuracy: 0.8570
#
# Epoch 00068: val_loss improved from 0.48267 to 0.48075, saving model to model.h5
# Epoch 69/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2789 - mae: 0.0227 - accuracy: 0.9083 - val_loss: 0.4848 - val_mae: 0.0295 - val_accuracy: 0.8576
#
# Epoch 00069: val_loss did not improve from 0.48075
# Epoch 70/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.2782 - mae: 0.0226 - accuracy: 0.9085 - val_loss: 0.4788 - val_mae: 0.0294 - val_accuracy: 0.8589
#
# Epoch 00070: val_loss improved from 0.48075 to 0.47879, saving model to model.h5
# Epoch 71/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2717 - mae: 0.0223 - accuracy: 0.9096 - val_loss: 0.4805 - val_mae: 0.0297 - val_accuracy: 0.8576
#
# Epoch 00071: val_loss did not improve from 0.47879
# Epoch 72/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2729 - mae: 0.0222 - accuracy: 0.9106 - val_loss: 0.4829 - val_mae: 0.0295 - val_accuracy: 0.8578
#
# Epoch 00072: val_loss did not improve from 0.47879
# Epoch 73/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2772 - mae: 0.0222 - accuracy: 0.9119 - val_loss: 0.4796 - val_mae: 0.0295 - val_accuracy: 0.8565
#
# Epoch 00073: val_loss did not improve from 0.47879
# Epoch 74/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2621 - mae: 0.0216 - accuracy: 0.9114 - val_loss: 0.4822 - val_mae: 0.0293 - val_accuracy: 0.8580
#
# Epoch 00074: val_loss did not improve from 0.47879
# Epoch 75/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2661 - mae: 0.0218 - accuracy: 0.9121 - val_loss: 0.4832 - val_mae: 0.0295 - val_accuracy: 0.8567
#
# Epoch 00075: val_loss did not improve from 0.47879
# Epoch 76/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2580 - mae: 0.0211 - accuracy: 0.9153 - val_loss: 0.4817 - val_mae: 0.0291 - val_accuracy: 0.8591
#
# Epoch 00076: val_loss did not improve from 0.47879
# Epoch 77/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2652 - mae: 0.0218 - accuracy: 0.9133 - val_loss: 0.4818 - val_mae: 0.0290 - val_accuracy: 0.8589
#
# Epoch 00077: val_loss did not improve from 0.47879
# Epoch 78/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.2588 - mae: 0.0211 - accuracy: 0.9163 - val_loss: 0.4841 - val_mae: 0.0291 - val_accuracy: 0.8591
#
# Epoch 00078: val_loss did not improve from 0.47879
# Epoch 79/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2619 - mae: 0.0215 - accuracy: 0.9136 - val_loss: 0.4856 - val_mae: 0.0293 - val_accuracy: 0.8578
#
# Epoch 00079: val_loss did not improve from 0.47879
# Epoch 80/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2607 - mae: 0.0214 - accuracy: 0.9142 - val_loss: 0.4849 - val_mae: 0.0292 - val_accuracy: 0.8598
#
# Epoch 00080: val_loss did not improve from 0.47879
# Epoch 81/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2599 - mae: 0.0211 - accuracy: 0.9154 - val_loss: 0.4833 - val_mae: 0.0291 - val_accuracy: 0.8600
#
# Epoch 00081: val_loss did not improve from 0.47879
# Epoch 82/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2598 - mae: 0.0210 - accuracy: 0.9159 - val_loss: 0.4843 - val_mae: 0.0291 - val_accuracy: 0.8574
#
# Epoch 00082: val_loss did not improve from 0.47879
# Epoch 83/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2493 - mae: 0.0208 - accuracy: 0.9166 - val_loss: 0.4850 - val_mae: 0.0289 - val_accuracy: 0.8596
#
# Epoch 00083: val_loss did not improve from 0.47879
# Epoch 84/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2575 - mae: 0.0212 - accuracy: 0.9141 - val_loss: 0.4835 - val_mae: 0.0289 - val_accuracy: 0.8576
#
# Epoch 00084: val_loss did not improve from 0.47879
# Epoch 85/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2584 - mae: 0.0210 - accuracy: 0.9143 - val_loss: 0.4827 - val_mae: 0.0288 - val_accuracy: 0.8600
#
# Epoch 00085: val_loss did not improve from 0.47879
# Epoch 86/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.2474 - mae: 0.0205 - accuracy: 0.9198 - val_loss: 0.4810 - val_mae: 0.0286 - val_accuracy: 0.8600
#
# Epoch 00086: val_loss did not improve from 0.47879
# Epoch 87/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2528 - mae: 0.0207 - accuracy: 0.9161 - val_loss: 0.4798 - val_mae: 0.0287 - val_accuracy: 0.8589
#
# Epoch 00087: val_loss did not improve from 0.47879
# Epoch 88/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2474 - mae: 0.0204 - accuracy: 0.9193 - val_loss: 0.4860 - val_mae: 0.0289 - val_accuracy: 0.8572
#
# Epoch 00088: val_loss did not improve from 0.47879
# Epoch 89/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2439 - mae: 0.0205 - accuracy: 0.9211 - val_loss: 0.4846 - val_mae: 0.0287 - val_accuracy: 0.8570
#
# Epoch 00089: val_loss did not improve from 0.47879
# Epoch 90/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.2451 - mae: 0.0202 - accuracy: 0.9186 - val_loss: 0.4912 - val_mae: 0.0289 - val_accuracy: 0.8559
#
# Epoch 00090: val_loss did not improve from 0.47879
# Epoch 91/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2362 - mae: 0.0198 - accuracy: 0.9216 - val_loss: 0.4817 - val_mae: 0.0286 - val_accuracy: 0.8596
#
# Epoch 00091: val_loss did not improve from 0.47879
# Epoch 92/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2430 - mae: 0.0201 - accuracy: 0.9210 - val_loss: 0.4894 - val_mae: 0.0288 - val_accuracy: 0.8567
#
# Epoch 00092: val_loss did not improve from 0.47879
# Epoch 93/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2402 - mae: 0.0201 - accuracy: 0.9209 - val_loss: 0.4836 - val_mae: 0.0282 - val_accuracy: 0.8606
#
# Epoch 00093: val_loss did not improve from 0.47879
# Epoch 94/100
# 563/563 [==============================] - 5s 10ms/step - loss: 0.2387 - mae: 0.0198 - accuracy: 0.9213 - val_loss: 0.4830 - val_mae: 0.0283 - val_accuracy: 0.8565
#
# Epoch 00094: val_loss did not improve from 0.47879
# Epoch 95/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2413 - mae: 0.0200 - accuracy: 0.9204 - val_loss: 0.4878 - val_mae: 0.0285 - val_accuracy: 0.8572
#
# Epoch 00095: val_loss did not improve from 0.47879
# Epoch 96/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2379 - mae: 0.0195 - accuracy: 0.9219 - val_loss: 0.4810 - val_mae: 0.0283 - val_accuracy: 0.8561
#
# Epoch 00096: val_loss did not improve from 0.47879
# Epoch 97/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2306 - mae: 0.0194 - accuracy: 0.9231 - val_loss: 0.4875 - val_mae: 0.0285 - val_accuracy: 0.8580
#
# Epoch 00097: val_loss did not improve from 0.47879
# Epoch 98/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2405 - mae: 0.0200 - accuracy: 0.9204 - val_loss: 0.4820 - val_mae: 0.0281 - val_accuracy: 0.8585
#
# Epoch 00098: val_loss did not improve from 0.47879
# Epoch 99/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2333 - mae: 0.0195 - accuracy: 0.9244 - val_loss: 0.4870 - val_mae: 0.0284 - val_accuracy: 0.8554
#
# Epoch 00099: val_loss did not improve from 0.47879
# Epoch 100/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.2385 - mae: 0.0199 - accuracy: 0.9200 - val_loss: 0.4820 - val_mae: 0.0280 - val_accuracy: 0.8583
#
# Epoch 00100: val_loss did not improve from 0.47879

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# summarize history for mae
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('model mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
model.save("classificationBBDC_Data_100.h5")

# %%
model = keras.models.load_model("model.h5")

# %%
prediction = model.predict(X_test)
scores = model.evaluate(X_test, Y_test[:,1:])
# Out:
# 140/140 [==============================] - 0s 2ms/step - loss: 0.5247 - mae: 0.0307 - accuracy: 0.8474

# %% [markdown]
# # Prediction der Test-Daten

# %%
firstPredictionFile = "./../data/test.csv" #"../predictions/jannes/LP1d_Prediction_mel_pp_test.csv"
firstPrediction = pd.read_csv(firstPredictionFile)
pathToDataDir = "../data/"
pathToDataset = "dataset_fft_mel_l04_o02495_f32/"
firstPrediction.head()
# Out:
#         filename     onset    offset event_label
# 0  09001_mix.wav  1.151324  3.151324       Cough
# 1  09001_mix.wav  3.884321  5.884321    Cheering
# 2  09001_mix.wav  7.726865  9.726865        Meow
# 3  09002_mix.wav  0.232286  1.232286       Shout
# 4  09002_mix.wav  2.679677  4.679677      Camera

# %%
currentFile = ""
X = []
Y = []
for index, row in firstPrediction.iterrows():
    if currentFile!=row["filename"]:
        currentFile = row["filename"]
        features = np.genfromtxt(pathToDataDir + pathToDataset +"/dev/" + row["filename"].replace(".wav", ".csv"), delimiter=',')
    indices = np.where(np.logical_and(features[:,0]>=row["onset"], features[:,0]<=row["offset"]))[0]
    start = indices[0]
    end = indices[-1]
    while end-start<44:
        start = start-10
        end = end+10
        if end>=len(features):
            end = len(features)
        if start<0:
            start=0
    X.append(features[start:end, 1:])

# %%
secondPrediction = []
secondProbability = []
for i in range(len(X)):
    if X[i].shape[0]>=44:
        prediction = model.predict(np.array([X[i]]))[0]
        mostLikely = np.argsort(prediction)[-1]+1
        secondLikely = np.argsort(prediction)[-2]+1
        secondPrediction.append(mostLikely)
        secondProbability.append(secondLikely)
    else:
        secondPrediction.append("short")
        secondProbability.append("short")
        print("too short")

secondLabel = [bbdc.invLabelMap[pred] for pred in secondPrediction]
secondProbLabel = [bbdc.invLabelMap[pred] for pred in secondProbability]

# %%
secondPredictionDf = firstPrediction.copy()
secondPredictionDf["event_label"]=secondLabel
secondPredictionDf2 = firstPrediction.copy()
secondPredictionDf2["event_label"]=secondLabel
secondPredictionDf = secondPredictionDf.append(secondPredictionDf2)
secondPredictionDf.to_csv("../predictions/jannes/predictionWithTwoLabels.csv", index=False)

# %%
print("Score was: ")
print(evaluate.evaluate(firstPredictionFile, "./../data/test.csv"))
print("Score now is: ")
print(evaluate.evaluate("../predictions/jannes/predictionWithTwoLabels.csv", "./../data/test.csv"))
# Out:
# Score was:
# (1.0, 'Valid file')
# Score now is:
# (0.6735387687262137, 'Valid file')

# %% [markdown]
# # Prediction der Challenge-Daten

# %%
pathToDataDir = "../data/"
pathToDataset = "dataset_fft_mel_l04_o02495_f32/"
firstPredictionFile = "../data/challenge_dummyWithTime.csv"
firstPrediction = pd.read_csv(firstPredictionFile)
firstPrediction.head()
# Out:
#         filename     onset    offset event_label
# 0  10001_mix.wav  2.857143  3.834586           ?
# 1  10001_mix.wav  5.488722  6.466165           ?
# 2  10001_mix.wav  7.969925  8.546366           ?
# 3  10001_mix.wav  9.573935  9.774436           ?
# 4  10002_mix.wav  0.451128  3.483709           ?

# %%
currentFile = ""
X = []
Y = []
for index, row in firstPrediction.iterrows():
    if currentFile!=row["filename"]:
        currentFile = row["filename"]
        features = np.genfromtxt(pathToDataDir + pathToDataset +"/eval/" + row["filename"].replace(".wav", ".csv"), delimiter=',')
    indices = np.where(np.logical_and(features[:,0]>=row["onset"], features[:,0]<=row["offset"]))[0]
    start = indices[0]
    end = indices[-1]
    while end-start<44:
        start = start-10
        end = end+10
        if end>=len(features):
            end = len(features)
        if start<0:
            start=0
    X.append(features[start:end, 1:])

# %%
secondPrediction = []
secondProbability = []
for i in range(len(X)):
    if X[i].shape[0]>=44:
        prediction = model.predict(np.array([X[i]]))[0]
        mostLikely = np.argsort(prediction)[-1]+1
        secondLikely = np.argsort(prediction)[-2]+1
        #if pred==0:
        #    secondPrediction.append("?")
        #else:
        secondPrediction.append(mostLikely)
        secondProbability.append(secondLikely)
    else:
        secondPrediction.append("short")
        secondProbability.append("short")
        print("too short")

secondLabel = [bbdc.invLabelMap[pred] for pred in secondPrediction]
secondProbLabel = [bbdc.invLabelMap[pred] for pred in secondProbability]
secondPredictionDf = firstPrediction.copy()
secondPredictionDf["event_label"]=secondLabel
secondPredictionDf["secondLikely_label"]=secondProbLabel
secondPredictionDf.to_csv("../predictions/jannes/secondPredictionChallengeWithSecondLikely.csv", index=False)
